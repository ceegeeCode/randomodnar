# %% [markdown]
# # Training and testing LSTM50 on the yeast genome

# %% [markdown]
# This short Jupyter notebook takes you through the main steps we did for our LSTM50 model on yeast.
# The code was originally written in Python 2.7, but has been amended for Python 3.6. We ran it in Google Colab where you can let a GPU run the training and prediction of the model (it's all set up and just there to use). If you want to run this on your own server/machine, you need to install Keras (we used v 2.1.6) and Tensorflow (we used tensorflow_gpu-1.12.0-cp27-none-linux_x86_64.whl).
# It may be easiest to create and environment in which you install these. And then invoke that environment
# with the kernel for this notebook (you'll need to install a few things for having your environment available among the kernels in your Jupyter session --- check the internet, there's lots of help).
#
# The commands below call code (functions) in various python modules that we created for our purposes. All
# these modules are included in the home Github repo of this notebook. So to run the code you must download/clone
# the repo contents to a folder on your machine/server.
#
# If you run the notebook in Google Colab you can place all code in a Google drive and then mount the drive. This makes the code available in the Colab session (and that's what we do below). Output is also placed there, so may may need a few Gb's of free space on your drive!
#
# The data needed here is the yeast genome, which you can download from various public sources, e.g. the UCSC
# genome site (http://www.genome.ucsc.edu/).
#
# We first mount a Google drive and then set some paths to where code and genome data are placed, and where to place output (you'll need to create these folders in your Google drive):

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Insert the directory
import sys
sys.path.insert(0,"/content/drive/MyDrive/DNA_proj/development/")
sys.path.insert(0,"/content/drive/MyDrive/DNA_proj/data/")
sys.path.insert(0,"/content/drive/MyDrive/DNA_proj/results/training/")
sys.path.insert(0,"/content/drive/MyDrive/DNA_proj/results/predictions/")
sys.path.insert(0,"/content/drive/MyDrive/DNA_proj/results/GCbias/")

# %%
rootGenome = "/content/drive/MyDrive/DNA_proj/data/"
fileName = "S288C_reference_sequence_R64-1-1_20110203.fsa"
fileGenome = rootGenome + fileName
chromoList = ['R64_chr1', 'R64_chr2', 'R64_chr3', 'R64_chr4', 'R64_chr5', 'R64_chr6', 'R64_chr7', 'R64_chr8','R64_chr9', 'R64_chr10', 'R64_chr11', 'R64_chr12','R64_chr13', 'R64_chr14', 'R64_chr15', 'R64_chr16','R64_chr17' ]

# %% [markdown]
# For training and validating the model we split the genome in two truly non-overlapping parts (you can skip this and just use e.g. an 80-20 split for training/validation).

# %%
import dnaNet_dataGen as dataGen

# %%
rootOutput =rootGenome
ext = '.txt'
chromoFileList = []
for ch in chromoList:
    chromoFileList.append( rootOutput + ch + ext )
fileNamePart1 =  r'/part1.txt'
fileNamePart2 =  r'/part2.txt'
splitNrPositions = [40000, 10000 ]
dataGen.splitChromoStrings(chromoFileList = chromoFileList, splitNrPositions = splitNrPositions,lineLength = 60,  rootOutput = rootOutput, fileNamePart1 = fileNamePart1, fileNamePart2 = fileNamePart2)
# Out:
# doneTheseChromos for part 1:  ['/content/drive/MyDrive/DNA_proj/data/R64_chr1.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr2.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr3.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr4.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr5.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr6.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr7.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr8.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr9.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr10.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr11.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr12.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr13.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr14.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr15.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr16.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr17.txt']
# Number of chromos in vs out:  17 17
# doneTheseChromos for part 2:  ['/content/drive/MyDrive/DNA_proj/data/R64_chr1.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr2.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr3.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr4.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr5.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr6.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr7.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr8.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr9.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr10.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr11.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr12.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr13.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr14.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr15.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr16.txt', '/content/drive/MyDrive/DNA_proj/data/R64_chr17.txt']
# Number of chromos in vs out:  17 17

# %% [markdown]
# For defining and training the model we will use a function called allInOneWithDynSampling_ConvLSTMmodel, which is placed in
# our dnaNet_LSTM module. The function is a 'wrapper': It covers the definition of the model and the configuration for the
# training process (and some more). It has a long list of arguments, here we use some of them. If you want to get deeper into its
# details, you will be best off by reading the code. If you manage to come to terms with it you will also know how to define new
# model types and plug them into this wrapper. For now let us first set the model details.
#
# The model architecture that we will use is a 'convolutional-LSTM'. We have coded our version in the function makeConv1DLSTMmodel
# (in dnaNet_LSTM). This function is then called from within allInOneWithDynSampling_ConvLSTMmodel with whatever argument values we
# have suppplied. We want a model with flank size 50, with an intial convolutional layer using 64 filters of size 4, two bidirectional LSTM-layers where the first is sequence-to-sequence and a final dense layer with 50 untis. So we set (don't worry about the many unexplained arguments):

# %%
usedThisModel = 'makeConv1DLSTMmodel'
customFlankSize = 50
#convo:
overlap = 0
pool_b = 0
poolAt = [1, 3] #not in use
maxPooling_b = 0
poolStrides = 1
lengthWindows = [4]
nrFilters = [256] 
filterStride = 1
padding = 'valid'
#lstm layers:
nrOfParallelLSTMstacks = 1 #parallel LSTMs
nrLSTMlayers = 1 #OBS: the run data file will record nrLSTMlayers as this number plus 1 if summarizingLSTMLayer_b == 1
summarizingLSTMLayer_b = 1
LSTMFiltersByLastConvFilters_b = 1
nrLSTMFilters = [-1]  #-1: just placeholder to be recorded in runData file
tryAveraging_b = 0
#Final dense layers:
finalDenseLayers_b = 1
hiddenUnits = [50]
inclFrqModel_b = 0
insertFrqModel_b = 0
#Additional
exonicInfoBinaryFileName  = ''

# %% [markdown]
# Next we set the configuration for the training process. First some sizes: Here we let the training consist of 20 rounds ('repeats') each of 10 'epochs' which in turn each consists of 100 steps of loading in a batch of 500 samples and updating the model parameters on it (the last four parameters are not in use, so just set to placeholder values). Each such round then comprises training on 500000 randomly picked samples; at completion of each round a validation is run on 100000 samples (nrTestSamples):

# %%
#In anger (yeast):
nrOuterLoops = 1
firstIterNr = 0
nrOfRepeats = 20
firstRepeatNr = 0 #if = n > 0: loads in model from repeatNr n-1 
testDataIntervalIdTotrainDataInterval_b = 1
trainTestSplitRatio = 0.8 #no used when we run training in splitExercise mode
nrEpochs = 10 
batchSize = 500
stepsPerEpoch = 100
trainDataIntervalStepSize = 0 
trainDataInterval = [0,15000000]
nrTestSamples = 100000
testDataInterval = [10000000,-12000000]

# %% [markdown]
# Second (still parameters for the training process) some parameters, the most important being what optimizer we use, learning rate at start and whether to include the reverse complement of each sample to the batch or not:

# %%
#!!!:
augmentWithRevComplementary_b = 0 
optimizer = 'ADAM' 
learningRate = 0.001 
chromoNameBound = 1000 
labelsCodetype = 0 #1: base pair type prediction
# 
dynSamplesTransformStyle_b = 0 
rootFrq = '' 
file = "" 
frqModelFileName = rootFrq + file 
flankSizeFrqModel = -1 
exclFrqModelFlanks_b = 0

## 
dropout_b = 0 
dropoutVal = 0.0 
momentum = 0.1 #but we use Adam here, so the value here isn't used
onlyOneRandomChromo_b = 0 
avoidChromo = [] 
on_binf_b = 1

# %% [markdown]
# Finally, set a model name and a path for where to place the output:

# %%
subStr = '1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00'

modelName = 'modelLSTM_' + subStr
modelDescr = subStr

rootOutput =  r"/content/drive/MyDrive/DNA_proj/results/training/"

# %% [markdown]
# Before we can call the allInOneWithDynSampling_ConvLSTMmodel wrapper, we must   see to that we have a GPU running for us and of course load the python module holding the wrapper:

# %%
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
import dnaNet_LSTM_v3_py3 as dnaNet

# %%
#This cell is just for the case that we have changed the code and need to reload:
import imp
imp.reload(dnaNet)
# Out:
# <module 'dnaNet_LSTM_v3_py3' from '/content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py'>

# %% [markdown]
# So now we are all set to run the wrapper with all the values we have set for its arguments above. The time this training takes depends on the GPU and our access to it (one or two hours is not unrealistic). When running, the wrapper writes files to the /results/training directory, which we set right above as rootOutput (see also top where we mounted the drive); in each round files defining the model as well as some keeping track of the training-results are stored; a 'runData.txt' file records the settings of the run.
#
# A note: if you want rather to run a 80-20 split version, you don't need to split the genome and when running the wrapper leave splitExercise_b out (or set it to 0); further let fileGenome point to the genome file and leave fileGenome_forVal out (or set it to ' ').

# %%
fileGenome = r"/content/drive/MyDrive/DNA_proj/data/part1.txt"
fileGenome_forVal = r"/content/drive/MyDrive/DNA_proj/data/part2.txt"
labelsCodetype = 0 #1: base pair type prediction
dnaNet.allInOneWithDynSampling_ConvLSTMmodel(splitExercise_b = 1, genomeFileName_forVal = fileGenome_forVal, rootOutput = rootOutput, usedThisModel = usedThisModel, labelsCodetype = labelsCodetype, nrOuterLoops = nrOuterLoops, firstIterNr = firstIterNr, nrOfRepeats = nrOfRepeats,  firstRepeatNr = firstRepeatNr, convLayers_b = 1, overlap = overlap, learningRate = learningRate, momentum = momentum,  genomeFileName = fileGenome, chromoNameBound = chromoNameBound, trainTestSplitRatio = trainTestSplitRatio, customFlankSize = customFlankSize, inclFrqModel_b = inclFrqModel_b, insertFrqModel_b = insertFrqModel_b, exclFrqModelFlanks_b = exclFrqModelFlanks_b, frqModelFileName = frqModelFileName, flankSizeFrqModel = flankSizeFrqModel, modelName = modelName, testDataIntervalIdTotrainDataInterval_b = testDataIntervalIdTotrainDataInterval_b, trainDataIntervalStepSize = trainDataIntervalStepSize, trainDataInterval0 = trainDataInterval , nrTestSamples = nrTestSamples, testDataInterval = testDataInterval,   genSamples_b = 1,  nrOfParallelLSTMstacks = nrOfParallelLSTMstacks, lengthWindows = lengthWindows, nrLSTMlayers = nrLSTMlayers, summarizingLSTMLayer_b = summarizingLSTMLayer_b, LSTMFiltersByLastConvFilters_b = LSTMFiltersByLastConvFilters_b, nrLSTMFilters = nrLSTMFilters, finalDenseLayers_b = finalDenseLayers_b, hiddenUnits = hiddenUnits, nrFilters = nrFilters, padding = padding, filterStride = filterStride, tryAveraging_b= tryAveraging_b, pool_b = pool_b, maxPooling_b = maxPooling_b, poolAt = poolAt, poolStrides = poolStrides, optimizer = optimizer, dropoutVal = dropoutVal, dropout_b = dropout_b, augmentWithRevComplementary_b = augmentWithRevComplementary_b, batchSize = batchSize, nrEpochs = nrEpochs, stepsPerEpoch = stepsPerEpoch, shuffle_b = 0, on_binf_b = on_binf_b)
# Out:
# Now at outer iteration:  0
# trainDataInterval  [0, 15000000]
# testDataInterval  [0, 15000000]
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 1000
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 1000
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 15000001
# Genome data file 1st line:
#   >ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]
#
# Found data for this chromosome: ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]
# 1 1 1
# Found data for this chromosome: ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]
# Found data for this chromosome: ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]
# Found data for this chromosome: ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]
# Found data for this chromosome: ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]
# Found data for this chromosome: ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]
# Found data for this chromosome: ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]
# Found data for this chromosome: ref|NC_001140| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VIII]
# Found data for this chromosome: ref|NC_001141| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IX]
# Found data for this chromosome: ref|NC_001142| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=X]
# Found data for this chromosome: ref|NC_001143| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XI]
# Found data for this chromosome: ref|NC_001144| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XII]
# Found data for this chromosome: ref|NC_001145| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIII]
# Found data for this chromosome: ref|NC_001146| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIV]
# Found data for this chromosome: ref|NC_001147| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XV]
# Found data for this chromosome: ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]
# Found data for this chromosome: ref|NC_001224| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [location=mitochondrion] [top=circular]
# [['ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]', 181024], ['ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]', 645922], ['ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]', 247748], ['ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]', 1220192], ['ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]', 458807], ['ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]', 211128], ['ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]', 865943], ['ref|NC_001140| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VIII]', 444576], ['ref|NC_001141| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IX]', 351338], ['ref|NC_001142| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=X]', 590416], ['ref|NC_001143| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XI]', 529071], ['ref|NC_001144| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XII]', 861720], ['ref|NC_001145| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIII]', 737491], ['ref|NC_001146| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIV]', 626910], ['ref|NC_001147| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XV]', 865943], ['ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]', 751287], ['ref|NC_001224| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [location=mitochondrion] [top=circular]', 66102]]
# []
# Length of genome sequence read in:9655618
# Length of exonic-info sequence read in:9655618
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:9655618
# Of these 268 are W's
# Length genome sequence, only ACGT's:9655618
# Read in data for these (chromos, len(chromo)):  [['ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]', 181024], ['ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]', 645922], ['ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]', 247748], ['ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]', 1220192], ['ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]', 458807], ['ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]', 211128], ['ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]', 865943], ['ref|NC_001140| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VIII]', 444576], ['ref|NC_001141| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IX]', 351338], ['ref|NC_001142| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=X]', 590416], ['ref|NC_001143| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XI]', 529071], ['ref|NC_001144| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XII]', 861720], ['ref|NC_001145| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIII]', 737491], ['ref|NC_001146| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIV]', 626910], ['ref|NC_001147| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XV]', 865943], ['ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]', 751287], ['ref|NC_001224| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [location=mitochondrion] [top=circular]', 66102]]
# I'm doing the split-exercise, and will be using this part of the splitted genome for validations:  /content/drive/MyDrive/DNA_proj/data/part2.txt
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 1000
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 1000
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 15000001
# Genome data file 1st line:
#   >ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]
#
# Found data for this chromosome: ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]
# 60 60 60
# Found data for this chromosome: ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]
# Found data for this chromosome: ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]
# Found data for this chromosome: ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]
# Found data for this chromosome: ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]
# Found data for this chromosome: ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]
# Found data for this chromosome: ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]
# Found data for this chromosome: ref|NC_001140| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VIII]
# Found data for this chromosome: ref|NC_001141| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IX]
# Found data for this chromosome: ref|NC_001142| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=X]
# Found data for this chromosome: ref|NC_001143| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XI]
# Found data for this chromosome: ref|NC_001144| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XII]
# Found data for this chromosome: ref|NC_001145| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIII]
# Found data for this chromosome: ref|NC_001146| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIV]
# Found data for this chromosome: ref|NC_001147| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XV]
# Found data for this chromosome: ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]
# Found data for this chromosome: ref|NC_001224| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [location=mitochondrion] [top=circular]
# [['ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]', 49205], ['ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]', 167297], ['ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]', 68887], ['ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]', 311805], ['ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]', 118092], ['ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]', 59046], ['ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]', 225043], ['ref|NC_001140| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VIII]', 118092], ['ref|NC_001141| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IX]', 88569], ['ref|NC_001142| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=X]', 155367], ['ref|NC_001143| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XI]', 137774], ['ref|NC_001144| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XII]', 216502], ['ref|NC_001145| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIII]', 186979], ['ref|NC_001146| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIV]', 157456], ['ref|NC_001147| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XV]', 225394], ['ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]', 196820], ['ref|NC_001224| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [location=mitochondrion] [top=circular]', 19682]]
# []
# Length of genome sequence read in:2502010
# Length of exonic-info sequence read in:2502010
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:2502010
# Of these 255 are W's
# Length genome sequence, only ACGT's:2502010
# Read in validation-data for these (chromos, len(chromo)):  [['ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]', 49205], ['ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]', 167297], ['ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]', 68887], ['ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]', 311805], ['ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]', 118092], ['ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]', 59046], ['ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]', 225043], ['ref|NC_001140| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VIII]', 118092], ['ref|NC_001141| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IX]', 88569], ['ref|NC_001142| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=X]', 155367], ['ref|NC_001143| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XI]', 137774], ['ref|NC_001144| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XII]', 216502], ['ref|NC_001145| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIII]', 186979], ['ref|NC_001146| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XIV]', 157456], ['ref|NC_001147| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XV]', 225394], ['ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]', 196820], ['ref|NC_001224| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [location=mitochondrion] [top=circular]', 19682]]
# lGenome: 9655618
# sizeInput is set to:  100
# Train-test split sizes (nr of positions of genome array):  9655618 2502010
# Build Conv1d plus LSTM model...
# First the 1d-convo, ba ...
# Left-hand shape after 1st convo  (None, 47, 256)
# Right-hand shape after 1st convo  (None, 47, 256)
# ...by!
# Left-hand shape after all convo's  (None, 47, 256)
# Right-hand shape after all convo's  (None, 47, 256)
# Then the lstm part ...
# I'm using these filter sizes for the lstms  [256]
# LSTM layer:  0
# Left-hand shape after after i'th LSTM (None, 47, 256)
# Right-hand shape after i'th LSTM  (None, 47, 256)
# Left-hand shape after 2nd LSTM  (None, 256)
# Right-hand shape after 2nd LSTM  (None, 256)
# Shape of concatenated LSTM output  (None, 512)
# Shape of LSTM-stacks output  (None, 512)
# Shape after final dense layer  (None, 50)
# Output shape  (None, 4)
# ... Model's build.
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 50, 4)]      0           []
#
#  input_2 (InputLayer)           [(None, 50, 4)]      0           []
#
#  conv1d (Conv1D)                (None, 47, 256)      4352        ['input_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 47, 256)      4352        ['input_2[0][0]']
#
#  lstm (LSTM)                    (None, 47, 256)      525312      ['conv1d[0][0]']
#
#  lstm_1 (LSTM)                  (None, 47, 256)      525312      ['conv1d_1[0][0]']
#
#  lstm_2 (LSTM)                  (None, 256)          525312      ['lstm[0][0]']
#
#  lstm_3 (LSTM)                  (None, 256)          525312      ['lstm_1[0][0]']
#
#  concatenate (Concatenate)      (None, 512)          0           ['lstm_2[0][0]',
#                                                                   'lstm_3[0][0]']
#
#  dense (Dense)                  (None, 50)           25650       ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 4)            204         ['dense[0][0]']
#
# ==================================================================================================
# Total params: 2,135,806
# Trainable params: 2,135,806
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Next: compile it ..
# Compiled model ...
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 2/10
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 38s 224ms/step - loss: 1.3564 - accuracy: 0.3290
# Epoch 3/10
# 100/100 [==============================] - 22s 224ms/step - loss: 1.3456 - accuracy: 0.3523
# Epoch 4/10
# 100/100 [==============================] - 23s 228ms/step - loss: 1.3399 - accuracy: 0.3602
# Epoch 5/10
# 100/100 [==============================] - 23s 228ms/step - loss: 1.3422 - accuracy: 0.3568
# Epoch 6/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3410 - accuracy: 0.3599
# Epoch 7/10
# 100/100 [==============================] - 23s 228ms/step - loss: 1.3392 - accuracy: 0.3586
# Epoch 8/10
# 100/100 [==============================] - 23s 228ms/step - loss: 1.3364 - accuracy: 0.3599
# Epoch 9/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3332 - accuracy: 0.3613
# Epoch 10/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3345 - accuracy: 0.3613
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3357731103897095
# Test accuracy: 0.3591499924659729
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr0
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 232ms/step - loss: 1.3337 - accuracy: 0.3595
# Epoch 3/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3325 - accuracy: 0.3610
# Epoch 4/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3334 - accuracy: 0.3585
# Epoch 5/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3297 - accuracy: 0.3643
# Epoch 6/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3291 - accuracy: 0.3665
# Epoch 7/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3290 - accuracy: 0.3670
# Epoch 8/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3270 - accuracy: 0.3677
# Epoch 9/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3299 - accuracy: 0.3652
# Epoch 10/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3261 - accuracy: 0.3685
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3285356760025024
# Test accuracy: 0.365119993686676
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr1
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 231ms/step - loss: 1.3312 - accuracy: 0.3632
# Epoch 3/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3267 - accuracy: 0.3672
# Epoch 4/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3312 - accuracy: 0.3627
# Epoch 5/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3320 - accuracy: 0.3645
# Epoch 6/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3313 - accuracy: 0.3638
# Epoch 7/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3300 - accuracy: 0.3681
# Epoch 8/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3266 - accuracy: 0.3677
# Epoch 9/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3287 - accuracy: 0.3658
# Epoch 10/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3272 - accuracy: 0.3691
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3267571926116943
# Test accuracy: 0.3661800026893616
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr2
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 230ms/step - loss: 1.3257 - accuracy: 0.3691
# Epoch 3/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3256 - accuracy: 0.3682
# Epoch 4/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3250 - accuracy: 0.3698
# Epoch 5/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3240 - accuracy: 0.3697
# Epoch 6/10
# 100/100 [==============================] - 23s 228ms/step - loss: 1.3230 - accuracy: 0.3701
# Epoch 7/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3210 - accuracy: 0.3717
# Epoch 8/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3219 - accuracy: 0.3712
# Epoch 9/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3223 - accuracy: 0.3711
# Epoch 10/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3242 - accuracy: 0.3708
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3219184875488281
# Test accuracy: 0.3705199956893921
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr3
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 29s 231ms/step - loss: 1.3226 - accuracy: 0.3677
# Epoch 3/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3215 - accuracy: 0.3699
# Epoch 4/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3212 - accuracy: 0.3712
# Epoch 5/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3252 - accuracy: 0.3673
# Epoch 6/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3308 - accuracy: 0.3634
# Epoch 7/10
# 100/100 [==============================] - 23s 228ms/step - loss: 1.3289 - accuracy: 0.3651
# Epoch 8/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3256 - accuracy: 0.3682
# Epoch 9/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3240 - accuracy: 0.3667
# Epoch 10/10
# 100/100 [==============================] - 23s 228ms/step - loss: 1.3241 - accuracy: 0.3682
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3236052989959717
# Test accuracy: 0.3694100081920624
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr4
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 231ms/step - loss: 1.3209 - accuracy: 0.3735
# Epoch 3/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3194 - accuracy: 0.3714
# Epoch 4/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3210 - accuracy: 0.3732
# Epoch 5/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3242 - accuracy: 0.3669
# Epoch 6/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3185 - accuracy: 0.3739
# Epoch 7/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3200 - accuracy: 0.3705
# Epoch 8/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3204 - accuracy: 0.3707
# Epoch 9/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3168 - accuracy: 0.3747
# Epoch 10/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3162 - accuracy: 0.3757
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3183401823043823
# Test accuracy: 0.37060999870300293
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr5
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 231ms/step - loss: 1.3176 - accuracy: 0.3747
# Epoch 3/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3222 - accuracy: 0.3730
# Epoch 4/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3223 - accuracy: 0.3695
# Epoch 5/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3213 - accuracy: 0.3699
# Epoch 6/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3203 - accuracy: 0.3704
# Epoch 7/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3182 - accuracy: 0.3722
# Epoch 8/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3164 - accuracy: 0.3753
# Epoch 9/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3202 - accuracy: 0.3724
# Epoch 10/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3192 - accuracy: 0.3733
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3176774978637695
# Test accuracy: 0.3746500015258789
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr6
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 231ms/step - loss: 1.3192 - accuracy: 0.3740
# Epoch 3/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3201 - accuracy: 0.3693
# Epoch 4/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3215 - accuracy: 0.3671
# Epoch 5/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3173 - accuracy: 0.3751
# Epoch 6/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3180 - accuracy: 0.3739
# Epoch 7/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3169 - accuracy: 0.3746
# Epoch 8/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3161 - accuracy: 0.3761
# Epoch 9/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3166 - accuracy: 0.3749
# Epoch 10/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3149 - accuracy: 0.3760
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3150471448898315
# Test accuracy: 0.374210000038147
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr7
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 29s 231ms/step - loss: 1.3183 - accuracy: 0.3738
# Epoch 3/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3203 - accuracy: 0.3716
# Epoch 4/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3198 - accuracy: 0.3739
# Epoch 5/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3216 - accuracy: 0.3727
# Epoch 6/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3174 - accuracy: 0.3739
# Epoch 7/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3184 - accuracy: 0.3716
# Epoch 8/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3186 - accuracy: 0.3745
# Epoch 9/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3173 - accuracy: 0.3741
# Epoch 10/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3171 - accuracy: 0.3719
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3148387670516968
# Test accuracy: 0.3754499852657318
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr8
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 230ms/step - loss: 1.3133 - accuracy: 0.3789
# Epoch 3/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3173 - accuracy: 0.3723
# Epoch 4/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3136 - accuracy: 0.3750
# Epoch 5/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3173 - accuracy: 0.3717
# Epoch 6/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3164 - accuracy: 0.3763
# Epoch 7/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3100 - accuracy: 0.3819
# Epoch 8/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3126 - accuracy: 0.3786
# Epoch 9/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3108 - accuracy: 0.3806
# Epoch 10/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3134 - accuracy: 0.3759
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3147965669631958
# Test accuracy: 0.3738600015640259
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr9
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 231ms/step - loss: 1.3136 - accuracy: 0.3767
# Epoch 3/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3115 - accuracy: 0.3812
# Epoch 4/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3121 - accuracy: 0.3780
# Epoch 5/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3115 - accuracy: 0.3784
# Epoch 6/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3110 - accuracy: 0.3810
# Epoch 7/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3104 - accuracy: 0.3799
# Epoch 8/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3092 - accuracy: 0.3763
# Epoch 9/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3112 - accuracy: 0.3778
# Epoch 10/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3107 - accuracy: 0.3814
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3127226829528809
# Test accuracy: 0.3768799901008606
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr10
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 29s 231ms/step - loss: 1.3123 - accuracy: 0.3784
# Epoch 3/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3139 - accuracy: 0.3771
# Epoch 4/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3157 - accuracy: 0.3743
# Epoch 5/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3137 - accuracy: 0.3768
# Epoch 6/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3076 - accuracy: 0.3841
# Epoch 7/10
# ...
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr13
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 232ms/step - loss: 1.3123 - accuracy: 0.3766
# Epoch 3/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3137 - accuracy: 0.3741
# Epoch 4/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3107 - accuracy: 0.3811
# Epoch 5/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3099 - accuracy: 0.3769
# Epoch 6/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3080 - accuracy: 0.3823
# Epoch 7/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3091 - accuracy: 0.3819
# Epoch 8/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3062 - accuracy: 0.3839
# Epoch 9/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3090 - accuracy: 0.3796
# Epoch 10/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3107 - accuracy: 0.3802
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.30729341506958
# Test accuracy: 0.3800300061702728
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr14
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 231ms/step - loss: 1.3093 - accuracy: 0.3815
# Epoch 3/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3073 - accuracy: 0.3817
# Epoch 4/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3067 - accuracy: 0.3855
# Epoch 5/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3052 - accuracy: 0.3827
# Epoch 6/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3045 - accuracy: 0.3844
# Epoch 7/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3051 - accuracy: 0.3829
# Epoch 8/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3070 - accuracy: 0.3794
# Epoch 9/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3055 - accuracy: 0.3852
# Epoch 10/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3055 - accuracy: 0.3846
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.308707356452942
# Test accuracy: 0.3793799877166748
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr15
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 230ms/step - loss: 1.3056 - accuracy: 0.3848
# Epoch 3/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3082 - accuracy: 0.3819
# Epoch 4/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3016 - accuracy: 0.3881
# Epoch 5/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3079 - accuracy: 0.3824
# Epoch 6/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3046 - accuracy: 0.3824
# Epoch 7/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3020 - accuracy: 0.3890
# Epoch 8/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3059 - accuracy: 0.3829
# Epoch 9/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3084 - accuracy: 0.3809
# Epoch 10/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3088 - accuracy: 0.3808
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3103021383285522
# Test accuracy: 0.37654998898506165
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr16
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 29s 230ms/step - loss: 1.3044 - accuracy: 0.3848
# Epoch 3/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3046 - accuracy: 0.3852
# Epoch 4/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3044 - accuracy: 0.3856
# Epoch 5/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3055 - accuracy: 0.3815
# Epoch 6/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3022 - accuracy: 0.3865
# Epoch 7/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3094 - accuracy: 0.3777
# Epoch 8/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3054 - accuracy: 0.3826
# Epoch 9/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3063 - accuracy: 0.3828
# Epoch 10/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3086 - accuracy: 0.3805
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3069136142730713
# Test accuracy: 0.3824099898338318
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr17
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 231ms/step - loss: 1.3076 - accuracy: 0.3839
# Epoch 3/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3055 - accuracy: 0.3849
# Epoch 4/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3045 - accuracy: 0.3848
# Epoch 5/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3033 - accuracy: 0.3854
# Epoch 6/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3002 - accuracy: 0.3870
# Epoch 7/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3043 - accuracy: 0.3823
# Epoch 8/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3053 - accuracy: 0.3842
# Epoch 9/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3034 - accuracy: 0.3867
# Epoch 10/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3033 - accuracy: 0.3845
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3018290996551514
# Test accuracy: 0.382750004529953
# I've now reloaded the model from the previous iteration (for test-only: for this repeatNr:  /content/drive/MyDrive/DNA_proj/results/training/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr18
# Next: compile it ..
# Compiled model ...
# Epoch 2/10
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2559: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = net.fit_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps_per_epoch= stepsPerEpoch, epochs=nrEpochs, verbose=1, callbacks=None, validation_data=None, validation_steps=None, class_weight=None, max_queue_size=2, workers=1, use_multiprocessing=False,  initial_epoch=1)
# 100/100 [==============================] - 30s 231ms/step - loss: 1.3007 - accuracy: 0.3853
# Epoch 3/10
# 100/100 [==============================] - 23s 231ms/step - loss: 1.3015 - accuracy: 0.3856
# Epoch 4/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3036 - accuracy: 0.3835
# Epoch 5/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3012 - accuracy: 0.3868
# Epoch 6/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.3029 - accuracy: 0.3851
# Epoch 7/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.3032 - accuracy: 0.3815
# Epoch 8/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.2992 - accuracy: 0.3867
# Epoch 9/10
# 100/100 [==============================] - 23s 229ms/step - loss: 1.2985 - accuracy: 0.3892
# Epoch 10/10
# 100/100 [==============================] - 23s 230ms/step - loss: 1.2988 - accuracy: 0.3872
# dict_keys(['loss', 'accuracy'])
# Now testing ...
# Split-exercise. The data for this test/validation are taken from another source than the train data
# Train-test split ratio set to: 0.259125
# /content/drive/MyDrive/DNA_proj/development/dnaNet_LSTM_v3_py3.py:2728: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   score, acc = net.evaluate_generator(myGenerator(customFlankSize,batchSize, oneSided_b, inclFrqModel_b, insertFrqModel_b, labelsCodetype, forTrain_b), steps = np.int(float(nrTestSamples)/batchSize))
# Test score: 1.3017898797988892
# Test accuracy: 0.38317999243736267

# %% [markdown]
# To examine the training process you can plot training-validation results with this call:

# %%
import dnaNet_plots as plots

bigLoopIterNr = 0
modelFileNameList = [rootOutput + 'modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00']

batchSizeRatioList = [1]
lastRepeatNrList = [nrOfRepeats -1]
epochsPerRepeatList = [10. -1] #you have to look up nrEpochs per repeat (the log file for the run, runData ); subtract 1 since epoch 1 in each repeat is apperently not saved

modelNameList = ['LSTM4']
fileNameAcc = 'LSTM4_total_trainTest_acc_vs_allEpochs'
fileNameLoss = 'LSTM4_total_trainTest_loss_vs_allEpochs'
plots.collectivePerfPlot(modelFileNameList = modelFileNameList, batchSizeRatioList = batchSizeRatioList, lastRepeatNrList = lastRepeatNrList, epochsPerRepeatList = epochsPerRepeatList, rootOutput = rootOutput, modelNameList = modelNameList, fileNameAcc= fileNameAcc, fileNameLoss = fileNameLoss )

# %% [markdown]
# When the training is done (and if we are satisfied with it), we can apply the trained model to DNA sequence. Here we want to let the model
# 'predict' on the complete yeast genome. To carry this out and many other tasks downstream of it, we use a python module dedicated to these purposes:

# %%
import dnaNet_stats_py3 as stats

# %% [markdown]
# Settings for the prediction (we segment the genome in 100kb pieces):

# %%
rootGenome = rootGenome #was set above
rootOutput = r"/content/drive/MyDrive/DNA_proj/results/predictions/"
rootModel = r"/content/drive/MyDrive/DNA_proj/results/training/"
lastRepeatNr = nrOfRepeats -1 
modelFileNameNN = "modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr" + str(lastRepeatNr)

augmentWithRevComplementary_b = 0
leftRight_b = 1
customFlankSize = 50
computePredAcc_b = 1
Fourier_b = 0

segmentLength = 1e5

batchSize = 528
windowLength = 1
stepSize = 1
Fourier_b = 0
on_binf_b = 1

#start positions
chromosomeOrderList = ['R64_chr1', 'R64_chr2', 'R64_chr3', 'R64_chr4', 'R64_chr5', 'R64_chr6', 'R64_chr7', 'R64_chr8','R64_chr9', 'R64_chr10', 'R64_chr11', 'R64_chr12','R64_chr13', 'R64_chr14', 'R64_chr15', 'R64_chr16']
chromosomeDict = {'R64_chr1':[0,1e8], 'R64_chr2':[0,1e8], 'R64_chr3':[0,1e8], 'R64_chr4':[0,1e8], 'R64_chr5':[0,1e8], 'R64_chr6':[0,1e8], 'R64_chr7':[0,1e8], 'R64_chr8':[0,1e8],'R64_chr9':[0,1e8], 'R64_chr10':[0,1e8], 'R64_chr11':[0,1e8], 'R64_chr12':[0,1e8],'R64_chr13':[0,1e8], 'R64_chr14':[0,1e8], 'R64_chr15':[0,1e8], 'R64_chr16':[0,1e8]}
startAtSegmentDict = {}

# %% [markdown]
# Run the predictions -- this may take a while too:

# %%
stats.predictOnChromosomes(rootGenome = rootGenome, 
                         chromosomeDict = chromosomeDict,
                         chromosomeOrderList = chromosomeOrderList, 
                         rootOutput = rootOutput,
                         rootModel = rootModel,
                         modelFileName = modelFileNameNN,
                        segmentLength = segmentLength,
                        augmentWithRevComplementary_b = augmentWithRevComplementary_b, #!!!!!
                        startAtSegmentDict = startAtSegmentDict,
                        customFlankSize = customFlankSize,
                        computePredAcc_b = computePredAcc_b, 
                        overlap = 0,
                        leftRight_b = leftRight_b, #use 1 for bi-directional models
                        batchSize = batchSize,
                        windowLength = windowLength,
                        stepSize = stepSize,
                        Fourier_b = Fourier_b,
                        on_binf_b = on_binf_b)
# Out:
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]
#
# Found data for this chromosome: ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]
# 60 60 60
# [['ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]', 230218]]
# []
# Length of genome sequence read in:230218
# Length of exonic-info sequence read in:230218
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:230218
# Of these 0 are W's
# Length genome sequence, only ACGT's:230218
# nrSegments:  2
# Now at segment  0
# Length of encoded genome sequence read in:  230218
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 38664 , cntTot: 99950 ; average prediction acc : 0.386833
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.386833
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.386833
# Now at segment  1
# Length of encoded genome sequence read in:  230218
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38355 , cntTot: 100000 ; average prediction acc : 0.383550
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383550
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.385191
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]
#
# Found data for this chromosome: ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]
# 60 60 60
# [['ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]', 813184]]
# []
# Length of genome sequence read in:813184
# Length of exonic-info sequence read in:813184
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:813184
# Of these 0 are W's
# Length genome sequence, only ACGT's:813184
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/ created. Output will be placed there.
# nrSegments:  8
# Now at segment  0
# Length of encoded genome sequence read in:  813184
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 38153 , cntTot: 99950 ; average prediction acc : 0.381721
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381721
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.381721
# Now at segment  1
# Length of encoded genome sequence read in:  813184
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38914 , cntTot: 100000 ; average prediction acc : 0.389140
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.389140
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.385431
# Now at segment  2
# Length of encoded genome sequence read in:  813184
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38091 , cntTot: 100000 ; average prediction acc : 0.380910
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.380910
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.383924
# Now at segment  3
# Length of encoded genome sequence read in:  813184
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39014 , cntTot: 100000 ; average prediction acc : 0.390140
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.390140
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.385478
# Now at segment  4
# Length of encoded genome sequence read in:  813184
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39363 , cntTot: 100000 ; average prediction acc : 0.393630
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.393630
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 4: 0.387109
# Now at segment  5
# Length of encoded genome sequence read in:  813184
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38837 , cntTot: 100000 ; average prediction acc : 0.388370
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.388370
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 5: 0.387319
# Now at segment  6
# Length of encoded genome sequence read in:  813184
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38322 , cntTot: 100000 ; average prediction acc : 0.383220
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383220
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 6: 0.386733
# Now at segment  7
# Length of encoded genome sequence read in:  813184
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38069 , cntTot: 100000 ; average prediction acc : 0.380690
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.380690
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 7: 0.385978
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]
#
# Found data for this chromosome: ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]
# 60 60 60
# [['ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]', 316620]]
# []
# Length of genome sequence read in:316620
# Length of exonic-info sequence read in:316620
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:316620
# Of these 0 are W's
# Length genome sequence, only ACGT's:316620
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/ created. Output will be placed there.
# nrSegments:  3
# Now at segment  0
# Length of encoded genome sequence read in:  316620
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 38543 , cntTot: 99950 ; average prediction acc : 0.385623
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385623
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.385623
# Now at segment  1
# Length of encoded genome sequence read in:  316620
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38274 , cntTot: 100000 ; average prediction acc : 0.382740
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.382740
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.384181
# Now at segment  2
# Length of encoded genome sequence read in:  316620
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38196 , cntTot: 100000 ; average prediction acc : 0.381960
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381960
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.383441
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]
#
# Found data for this chromosome: ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]
# 60 60 60
# [['ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]', 1531933]]
# []
# Length of genome sequence read in:1531933
# Length of exonic-info sequence read in:1531933
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:1531933
# Of these 0 are W's
# Length genome sequence, only ACGT's:1531933
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/ created. Output will be placed there.
# nrSegments:  15
# Now at segment  0
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 38074 , cntTot: 99950 ; average prediction acc : 0.380930
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.380930
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.380930
# Now at segment  1
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39277 , cntTot: 100000 ; average prediction acc : 0.392770
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.392770
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.386852
# Now at segment  2
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38552 , cntTot: 100000 ; average prediction acc : 0.385520
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385520
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.386408
# Now at segment  3
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39382 , cntTot: 100000 ; average prediction acc : 0.393820
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.393820
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.388261
# Now at segment  4
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38831 , cntTot: 100000 ; average prediction acc : 0.388310
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.388310
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 4: 0.388271
# Now at segment  5
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39290 , cntTot: 100000 ; average prediction acc : 0.392900
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.392900
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 5: 0.389042
# Now at segment  6
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38802 , cntTot: 100000 ; average prediction acc : 0.388020
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.388020
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 6: 0.388896
# Now at segment  7
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38857 , cntTot: 100000 ; average prediction acc : 0.388570
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.388570
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 7: 0.388856
# Now at segment  8
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39128 , cntTot: 100000 ; average prediction acc : 0.391280
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.391280
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 8: 0.389125
# Now at segment  9
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38661 , cntTot: 100000 ; average prediction acc : 0.386610
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.386610
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 9: 0.388873
# Now at segment  10
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38568 , cntTot: 100000 ; average prediction acc : 0.385680
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385680
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 10: 0.388583
# Now at segment  11
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38903 , cntTot: 100000 ; average prediction acc : 0.389030
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.389030
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 11: 0.388620
# Now at segment  12
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38765 , cntTot: 100000 ; average prediction acc : 0.387650
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.387650
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 12: 0.388546
# Now at segment  13
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38662 , cntTot: 100000 ; average prediction acc : 0.386620
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.386620
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 13: 0.388408
# Now at segment  14
# Length of encoded genome sequence read in:  1531933
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38890 , cntTot: 100000 ; average prediction acc : 0.388900
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.388900
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 14: 0.388441
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]
#
# Found data for this chromosome: ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]
# 60 60 60
# [['ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]', 576874]]
# []
# Length of genome sequence read in:576874
# Length of exonic-info sequence read in:576874
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:576874
# Of these 0 are W's
# Length genome sequence, only ACGT's:576874
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/ created. Output will be placed there.
# nrSegments:  5
# Now at segment  0
# Length of encoded genome sequence read in:  576874
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 37746 , cntTot: 99950 ; average prediction acc : 0.377649
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.377649
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.377649
# Now at segment  1
# Length of encoded genome sequence read in:  576874
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38442 , cntTot: 100000 ; average prediction acc : 0.384420
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384420
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.381035
# Now at segment  2
# Length of encoded genome sequence read in:  576874
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38379 , cntTot: 100000 ; average prediction acc : 0.383790
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383790
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.381954
# Now at segment  3
# Length of encoded genome sequence read in:  576874
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38791 , cntTot: 100000 ; average prediction acc : 0.387910
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.387910
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.383443
# Now at segment  4
# Length of encoded genome sequence read in:  576874
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38139 , cntTot: 100000 ; average prediction acc : 0.381390
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381390
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 4: 0.383032
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]
#
# Found data for this chromosome: ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]
# 60 60 60
# [['ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]', 270161]]
# []
# Length of genome sequence read in:270161
# Length of exonic-info sequence read in:270161
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:270161
# Of these 0 are W's
# Length genome sequence, only ACGT's:270161
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/ created. Output will be placed there.
# nrSegments:  2
# Now at segment  0
# Length of encoded genome sequence read in:  270161
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 37893 , cntTot: 99950 ; average prediction acc : 0.379120
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.379120
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.379120
# Now at segment  1
# Length of encoded genome sequence read in:  270161
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38924 , cntTot: 100000 ; average prediction acc : 0.389240
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.389240
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.384181
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]
#
# Found data for this chromosome: ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]
# 60 60 60
# [['ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]', 1090940]]
# []
# Length of genome sequence read in:1090940
# Length of exonic-info sequence read in:1090940
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:1090940
# Of these 0 are W's
# Length genome sequence, only ACGT's:1090940
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/ created. Output will be placed there.
# nrSegments:  10
# Now at segment  0
# Length of encoded genome sequence read in:  1090940
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 38767 , cntTot: 99950 ; average prediction acc : 0.387864
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.387864
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.387864
# Now at segment  1
# Length of encoded genome sequence read in:  1090940
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38784 , cntTot: 100000 ; average prediction acc : 0.387840
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.387840
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.387852
# Now at segment  2
# Length of encoded genome sequence read in:  1090940
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38343 , cntTot: 100000 ; average prediction acc : 0.383430
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383430
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.386378
# Now at segment  3
# Length of encoded genome sequence read in:  1090940
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38822 , cntTot: 100000 ; average prediction acc : 0.388220
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.388220
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.386838
# Now at segment  4
# Length of encoded genome sequence read in:  1090940
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39015 , cntTot: 100000 ; average prediction acc : 0.390150
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.390150
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 4: 0.387501
# Now at segment  5
# Length of encoded genome sequence read in:  1090940
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 37850 , cntTot: 100000 ; average prediction acc : 0.378500
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378500
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 5: 0.386001
# Now at segment  6
# Length of encoded genome sequence read in:  1090940
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39154 , cntTot: 100000 ; average prediction acc : 0.391540
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.391540
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 6: 0.386792
# Now at segment  7
# Length of encoded genome sequence read in:  1090940
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38584 , cntTot: 100000 ; average prediction acc : 0.385840
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385840
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 7: 0.386673
# Now at segment  8
# Length of encoded genome sequence read in:  1090940
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39181 , cntTot: 100000 ; average prediction acc : 0.391810
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.391810
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 8: 0.387244
# Now at segment  9
# Length of encoded genome sequence read in:  1090940
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38486 , cntTot: 100000 ; average prediction acc : 0.384860
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384860
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 9: 0.387005
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001140| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VIII]
#
# Found data for this chromosome: ref|NC_001140| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VIII]
# 60 60 60
# [['ref|NC_001140| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VIII]', 562643]]
# []
# Length of genome sequence read in:562643
# Length of exonic-info sequence read in:562643
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:562643
# Of these 0 are W's
# Length genome sequence, only ACGT's:562643
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr8/ created. Output will be placed there.
# nrSegments:  5
# Now at segment  0
# Length of encoded genome sequence read in:  562643
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 37862 , cntTot: 99950 ; average prediction acc : 0.378809
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378809
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.378809
# Now at segment  1
# Length of encoded genome sequence read in:  562643
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38443 , cntTot: 100000 ; average prediction acc : 0.384430
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384430
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.381620
# Now at segment  2
# Length of encoded genome sequence read in:  562643
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38745 , cntTot: 100000 ; average prediction acc : 0.387450
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.387450
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.383564
# Now at segment  3
# Length of encoded genome sequence read in:  562643
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38117 , cntTot: 100000 ; average prediction acc : 0.381170
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381170
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.382965
# Now at segment  4
# Length of encoded genome sequence read in:  562643
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38193 , cntTot: 100000 ; average prediction acc : 0.381930
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381930
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 4: 0.382758
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001141| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IX]
#
# Found data for this chromosome: ref|NC_001141| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IX]
# 60 60 60
# [['ref|NC_001141| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IX]', 439888]]
# []
# Length of genome sequence read in:439888
# Length of exonic-info sequence read in:439888
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:439888
# Of these 0 are W's
# Length genome sequence, only ACGT's:439888
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr9/ created. Output will be placed there.
# nrSegments:  4
# Now at segment  0
# Length of encoded genome sequence read in:  439888
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 38361 , cntTot: 99950 ; average prediction acc : 0.383802
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383802
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.383802
# Now at segment  1
# Length of encoded genome sequence read in:  439888
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39048 , cntTot: 100000 ; average prediction acc : 0.390480
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.390480
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.387142
# Now at segment  2
# Length of encoded genome sequence read in:  439888
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38339 , cntTot: 100000 ; average prediction acc : 0.383390
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383390
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.385891
# Now at segment  3
# Length of encoded genome sequence read in:  439888
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 37891 , cntTot: 100000 ; average prediction acc : 0.378910
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378910
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.384146
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001142| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=X]
#
# Found data for this chromosome: ref|NC_001142| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=X]
# 60 60 60
# [['ref|NC_001142| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=X]', 745751]]
# []
# Length of genome sequence read in:745751
# Length of exonic-info sequence read in:745751
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:745751
# Of these 0 are W's
# Length genome sequence, only ACGT's:745751
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr10/ created. Output will be placed there.
# nrSegments:  7
# Now at segment  0
# Length of encoded genome sequence read in:  745751
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 37867 , cntTot: 99950 ; average prediction acc : 0.378859
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378859
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.378859
# Now at segment  1
# Length of encoded genome sequence read in:  745751
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38620 , cntTot: 100000 ; average prediction acc : 0.386200
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.386200
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.382531
# Now at segment  2
# Length of encoded genome sequence read in:  745751
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38509 , cntTot: 100000 ; average prediction acc : 0.385090
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385090
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.383384
# Now at segment  3
# Length of encoded genome sequence read in:  745751
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38765 , cntTot: 100000 ; average prediction acc : 0.387650
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.387650
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.384451
# Now at segment  4
# Length of encoded genome sequence read in:  745751
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38193 , cntTot: 100000 ; average prediction acc : 0.381930
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381930
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 4: 0.383946
# Now at segment  5
# Length of encoded genome sequence read in:  745751
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38473 , cntTot: 100000 ; average prediction acc : 0.384730
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384730
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 5: 0.384077
# Now at segment  6
# Length of encoded genome sequence read in:  745751
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38585 , cntTot: 100000 ; average prediction acc : 0.385850
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385850
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 6: 0.384330
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001143| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XI]
#
# Found data for this chromosome: ref|NC_001143| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XI]
# 60 60 60
# [['ref|NC_001143| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XI]', 666816]]
# []
# Length of genome sequence read in:666816
# Length of exonic-info sequence read in:666816
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:666816
# Of these 0 are W's
# Length genome sequence, only ACGT's:666816
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr11/ created. Output will be placed there.
# nrSegments:  6
# Now at segment  0
# Length of encoded genome sequence read in:  666816
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 37612 , cntTot: 99950 ; average prediction acc : 0.376308
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.376308
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.376308
# Now at segment  1
# Length of encoded genome sequence read in:  666816
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38989 , cntTot: 100000 ; average prediction acc : 0.389890
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.389890
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.383101
# Now at segment  2
# Length of encoded genome sequence read in:  666816
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38962 , cntTot: 100000 ; average prediction acc : 0.389620
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.389620
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.385274
# Now at segment  3
# Length of encoded genome sequence read in:  666816
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38842 , cntTot: 100000 ; average prediction acc : 0.388420
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.388420
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.386061
# Now at segment  4
# Length of encoded genome sequence read in:  666816
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38953 , cntTot: 100000 ; average prediction acc : 0.389530
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.389530
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 4: 0.386755
# Now at segment  5
# Length of encoded genome sequence read in:  666816
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38692 , cntTot: 100000 ; average prediction acc : 0.386920
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.386920
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 5: 0.386782
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001144| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XII]
#
# Found data for this chromosome: ref|NC_001144| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XII]
# 60 60 60
# [['ref|NC_001144| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XII]', 1078177]]
# []
# Length of genome sequence read in:1078177
# Length of exonic-info sequence read in:1078177
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:1078177
# Of these 0 are W's
# Length genome sequence, only ACGT's:1078177
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr12/ created. Output will be placed there.
# nrSegments:  10
# Now at segment  0
# ...
# Of these 0 are W's
# Length genome sequence, only ACGT's:784333
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr14/ created. Output will be placed there.
# nrSegments:  7
# Now at segment  0
# Length of encoded genome sequence read in:  784333
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 37360 , cntTot: 99950 ; average prediction acc : 0.373787
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.373787
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.373787
# Now at segment  1
# Length of encoded genome sequence read in:  784333
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38404 , cntTot: 100000 ; average prediction acc : 0.384040
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384040
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.378915
# Now at segment  2
# Length of encoded genome sequence read in:  784333
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39373 , cntTot: 100000 ; average prediction acc : 0.393730
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.393730
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.383854
# Now at segment  3
# Length of encoded genome sequence read in:  784333
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38506 , cntTot: 100000 ; average prediction acc : 0.385060
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385060
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.384156
# Now at segment  4
# Length of encoded genome sequence read in:  784333
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38656 , cntTot: 100000 ; average prediction acc : 0.386560
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.386560
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 4: 0.384636
# Now at segment  5
# Length of encoded genome sequence read in:  784333
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38180 , cntTot: 100000 ; average prediction acc : 0.381800
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381800
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 5: 0.384164
# Now at segment  6
# Length of encoded genome sequence read in:  784333
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38129 , cntTot: 100000 ; average prediction acc : 0.381290
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381290
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 6: 0.383753
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001147| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XV]
#
# Found data for this chromosome: ref|NC_001147| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XV]
# 60 60 60
# [['ref|NC_001147| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XV]', 1091291]]
# []
# Length of genome sequence read in:1091291
# Length of exonic-info sequence read in:1091291
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:1091291
# Of these 0 are W's
# Length genome sequence, only ACGT's:1091291
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/ created. Output will be placed there.
# nrSegments:  10
# Now at segment  0
# Length of encoded genome sequence read in:  1091291
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 37578 , cntTot: 99950 ; average prediction acc : 0.375968
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.375968
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.375968
# Now at segment  1
# Length of encoded genome sequence read in:  1091291
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38555 , cntTot: 100000 ; average prediction acc : 0.385550
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385550
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.380760
# Now at segment  2
# Length of encoded genome sequence read in:  1091291
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38412 , cntTot: 100000 ; average prediction acc : 0.384120
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384120
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.381880
# Now at segment  3
# Length of encoded genome sequence read in:  1091291
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38320 , cntTot: 100000 ; average prediction acc : 0.383200
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383200
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.382210
# Now at segment  4
# Length of encoded genome sequence read in:  1091291
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38554 , cntTot: 100000 ; average prediction acc : 0.385540
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385540
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 4: 0.382876
# Now at segment  5
# Length of encoded genome sequence read in:  1091291
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38659 , cntTot: 100000 ; average prediction acc : 0.386590
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.386590
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 5: 0.383495
# Now at segment  6
# Length of encoded genome sequence read in:  1091291
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38696 , cntTot: 100000 ; average prediction acc : 0.386960
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.386960
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 6: 0.383990
# Now at segment  7
# Length of encoded genome sequence read in:  1091291
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39005 , cntTot: 100000 ; average prediction acc : 0.390050
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.390050
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 7: 0.384748
# Now at segment  8
# Length of encoded genome sequence read in:  1091291
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38564 , cntTot: 100000 ; average prediction acc : 0.385640
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385640
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 8: 0.384847
# Now at segment  9
# Length of encoded genome sequence read in:  1091291
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38236 , cntTot: 100000 ; average prediction acc : 0.382360
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.382360
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 9: 0.384598
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 100
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]
#
# Found data for this chromosome: ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]
# 60 60 60
# [['ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]', 948066]]
# []
# Length of genome sequence read in:948066
# Length of exonic-info sequence read in:948066
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:948066
# Of these 0 are W's
# Length genome sequence, only ACGT's:948066
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/ created. Output will be placed there.
# nrSegments:  9
# Now at segment  0
# Length of encoded genome sequence read in:  948066
# Nr of samples to be generated:  99950
# Nr of sampled positions: 99950
# Yt shape  (99950, 4)
# Xt_lr shape  (99950, 2, 50, 4)
# Nr of samples: 99950 ; of which are predicted: 99950
# lSamples  99950 , nrSteps  99950
# cntCorr: 37833 , cntTot: 99950 ; average prediction acc : 0.378519
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378519
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 0: 0.378519
# Now at segment  1
# Length of encoded genome sequence read in:  948066
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 39882 , cntTot: 100000 ; average prediction acc : 0.398820
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.398820
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 1: 0.388672
# Now at segment  2
# Length of encoded genome sequence read in:  948066
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38087 , cntTot: 100000 ; average prediction acc : 0.380870
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.380870
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 2: 0.386071
# Now at segment  3
# Length of encoded genome sequence read in:  948066
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38961 , cntTot: 100000 ; average prediction acc : 0.389610
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.389610
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 3: 0.386956
# Now at segment  4
# Length of encoded genome sequence read in:  948066
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38854 , cntTot: 100000 ; average prediction acc : 0.388540
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.388540
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 4: 0.387273
# Now at segment  5
# Length of encoded genome sequence read in:  948066
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38274 , cntTot: 100000 ; average prediction acc : 0.382740
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.382740
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 5: 0.386517
# Now at segment  6
# Length of encoded genome sequence read in:  948066
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38385 , cntTot: 100000 ; average prediction acc : 0.383850
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383850
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 6: 0.386136
# Now at segment  7
# Length of encoded genome sequence read in:  948066
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38334 , cntTot: 100000 ; average prediction acc : 0.383340
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383340
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 7: 0.385787
# Now at segment  8
# Length of encoded genome sequence read in:  948066
# Nr of samples to be generated:  100000
# Nr of sampled positions: 100000
# Yt shape  (100000, 4)
# Xt_lr shape  (100000, 2, 50, 4)
# Nr of samples: 100000 ; of which are predicted: 100000
# lSamples  100000 , nrSteps  100000
# cntCorr: 38498 , cntTot: 100000 ; average prediction acc : 0.384980
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384980
# No repeat sections were recorded in the genome data.
# Average prediction acc after segment 8: 0.385697

# %%
#Yeast:
segmentLength = 100000

averageRevComplementary_b = 0

chromosomeOrderList = ['R64_chr1', 'R64_chr2', 'R64_chr3', 'R64_chr4', 'R64_chr5', 'R64_chr6', 'R64_chr7', 'R64_chr8','R64_chr9', 'R64_chr10', 'R64_chr11', 'R64_chr12','R64_chr13', 'R64_chr14', 'R64_chr15', 'R64_chr16' ]
chromosomeDict = {'R64_chr1':[0,1e8], 'R64_chr2':[0,1e8], 'R64_chr3':[0,1e8], 'R64_chr4':[0,1e8], 'R64_chr5':[0,1e8], 'R64_chr6':[0,1e8], 'R64_chr7':[0,1e8], 'R64_chr8':[0,1e8],'R64_chr9':[0,1e8], 'R64_chr10':[0,1e8], 'R64_chr11':[0,1e8], 'R64_chr12':[0,1e8],'R64_chr13':[0,1e8], 'R64_chr14':[0,1e8], 'R64_chr15':[0,1e8], 'R64_chr16':[0,1e8]}
rootAnnotationFiles = r"/content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/"
annotationTypes = ['simpleRepeats']

# %% [markdown]
# This call computes accuracy-figures per segment and saves the results in dictionaries:

# %%
resultsDictByAnnoSeg, resultsDictByAnno  = stats.getAccuracyChromosomes(chromosomeOrderList = chromosomeOrderList, 
                         rootOutput = rootOutput,
                         modelFileName = modelFileNameNN, 
                         segmentLength = segmentLength,
                         averageRevComplementary_b = averageRevComplementary_b,
                         windowLength = windowLength,
                         stepSize = stepSize, 
                         annotationTypes = annotationTypes,
                         rootAnnotationFiles = rootAnnotationFiles,
                         chromosomeDict = chromosomeDict)
# Out:
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr1_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr1_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr1/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr1_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr1_seg100000_segment0: 0.386830 based on corr 38664 and tot 99950
# Acc at R64_chr1_seg100000_segment0 as recorded/done in computeAcc: 0.386830 , based on nr of corr 38664, tot cnt 99950
# Acc at R64_chr1_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr1/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr1_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr1_seg100000_segment1: 0.383546 based on corr 38355 and tot 100000
# Acc at R64_chr1_seg100000_segment1 as recorded/done in computeAcc: 0.383546 , based on nr of corr 38355, tot cnt 100000
# Acc at R64_chr1_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr1/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr1_seg100000_segment2_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr2_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr2_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr2_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr2_seg100000_segment0: 0.381717 based on corr 38153 and tot 99950
# Acc at R64_chr2_seg100000_segment0 as recorded/done in computeAcc: 0.381717 , based on nr of corr 38153, tot cnt 99950
# Acc at R64_chr2_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr2_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr2_seg100000_segment1: 0.389136 based on corr 38914 and tot 100000
# Acc at R64_chr2_seg100000_segment1 as recorded/done in computeAcc: 0.389136 , based on nr of corr 38914, tot cnt 100000
# Acc at R64_chr2_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr2_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr2_seg100000_segment2: 0.380906 based on corr 38091 and tot 100000
# Acc at R64_chr2_seg100000_segment2 as recorded/done in computeAcc: 0.380906 , based on nr of corr 38091, tot cnt 100000
# Acc at R64_chr2_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr2_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr2_seg100000_segment3: 0.390136 based on corr 39014 and tot 100000
# Acc at R64_chr2_seg100000_segment3 as recorded/done in computeAcc: 0.390136 , based on nr of corr 39014, tot cnt 100000
# Acc at R64_chr2_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr2_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# 100000
# Acc at R64_chr2_seg100000_segment4: 0.393626 based on corr 39363 and tot 100000
# Acc at R64_chr2_seg100000_segment4 as recorded/done in computeAcc: 0.393626 , based on nr of corr 39363, tot cnt 100000
# Acc at R64_chr2_seg100000_segment4 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr2_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# 100000
# Acc at R64_chr2_seg100000_segment5: 0.388366 based on corr 38837 and tot 100000
# Acc at R64_chr2_seg100000_segment5 as recorded/done in computeAcc: 0.388366 , based on nr of corr 38837, tot cnt 100000
# Acc at R64_chr2_seg100000_segment5 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr2_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# 100000
# Acc at R64_chr2_seg100000_segment6: 0.383216 based on corr 38322 and tot 100000
# Acc at R64_chr2_seg100000_segment6 as recorded/done in computeAcc: 0.383216 , based on nr of corr 38322, tot cnt 100000
# Acc at R64_chr2_seg100000_segment6 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr2_seg100000_segment7_avgRevCompl0_win1_step1
# 7 (100000,)
# 100000
# 100000
# Acc at R64_chr2_seg100000_segment7: 0.380686 based on corr 38069 and tot 100000
# Acc at R64_chr2_seg100000_segment7 as recorded/done in computeAcc: 0.380686 , based on nr of corr 38069, tot cnt 100000
# Acc at R64_chr2_seg100000_segment7 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr2_seg100000_segment8_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr3_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr3_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr3_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr3_seg100000_segment0: 0.385619 based on corr 38543 and tot 99950
# Acc at R64_chr3_seg100000_segment0 as recorded/done in computeAcc: 0.385619 , based on nr of corr 38543, tot cnt 99950
# Acc at R64_chr3_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr3_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr3_seg100000_segment1: 0.382736 based on corr 38274 and tot 100000
# Acc at R64_chr3_seg100000_segment1 as recorded/done in computeAcc: 0.382736 , based on nr of corr 38274, tot cnt 100000
# Acc at R64_chr3_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr3_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr3_seg100000_segment2: 0.381956 based on corr 38196 and tot 100000
# Acc at R64_chr3_seg100000_segment2 as recorded/done in computeAcc: 0.381956 , based on nr of corr 38196, tot cnt 100000
# Acc at R64_chr3_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr3_seg100000_segment3_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr4_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr4_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr4_seg100000_segment0: 0.380927 based on corr 38074 and tot 99950
# Acc at R64_chr4_seg100000_segment0 as recorded/done in computeAcc: 0.380927 , based on nr of corr 38074, tot cnt 99950
# Acc at R64_chr4_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment1: 0.392766 based on corr 39277 and tot 100000
# Acc at R64_chr4_seg100000_segment1 as recorded/done in computeAcc: 0.392766 , based on nr of corr 39277, tot cnt 100000
# Acc at R64_chr4_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment2: 0.385516 based on corr 38552 and tot 100000
# Acc at R64_chr4_seg100000_segment2 as recorded/done in computeAcc: 0.385516 , based on nr of corr 38552, tot cnt 100000
# Acc at R64_chr4_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment3: 0.393816 based on corr 39382 and tot 100000
# Acc at R64_chr4_seg100000_segment3 as recorded/done in computeAcc: 0.393816 , based on nr of corr 39382, tot cnt 100000
# Acc at R64_chr4_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment4: 0.388306 based on corr 38831 and tot 100000
# Acc at R64_chr4_seg100000_segment4 as recorded/done in computeAcc: 0.388306 , based on nr of corr 38831, tot cnt 100000
# Acc at R64_chr4_seg100000_segment4 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment5: 0.392896 based on corr 39290 and tot 100000
# Acc at R64_chr4_seg100000_segment5 as recorded/done in computeAcc: 0.392896 , based on nr of corr 39290, tot cnt 100000
# Acc at R64_chr4_seg100000_segment5 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment6: 0.388016 based on corr 38802 and tot 100000
# Acc at R64_chr4_seg100000_segment6 as recorded/done in computeAcc: 0.388016 , based on nr of corr 38802, tot cnt 100000
# Acc at R64_chr4_seg100000_segment6 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment7_avgRevCompl0_win1_step1
# 7 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment7: 0.388566 based on corr 38857 and tot 100000
# Acc at R64_chr4_seg100000_segment7 as recorded/done in computeAcc: 0.388566 , based on nr of corr 38857, tot cnt 100000
# Acc at R64_chr4_seg100000_segment7 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment8_avgRevCompl0_win1_step1
# 8 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment8: 0.391276 based on corr 39128 and tot 100000
# Acc at R64_chr4_seg100000_segment8 as recorded/done in computeAcc: 0.391276 , based on nr of corr 39128, tot cnt 100000
# Acc at R64_chr4_seg100000_segment8 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment9_avgRevCompl0_win1_step1
# 9 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment9: 0.386606 based on corr 38661 and tot 100000
# Acc at R64_chr4_seg100000_segment9 as recorded/done in computeAcc: 0.386606 , based on nr of corr 38661, tot cnt 100000
# Acc at R64_chr4_seg100000_segment9 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment10_avgRevCompl0_win1_step1
# 10 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment10: 0.385676 based on corr 38568 and tot 100000
# Acc at R64_chr4_seg100000_segment10 as recorded/done in computeAcc: 0.385676 , based on nr of corr 38568, tot cnt 100000
# Acc at R64_chr4_seg100000_segment10 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment11_avgRevCompl0_win1_step1
# 11 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment11: 0.389026 based on corr 38903 and tot 100000
# Acc at R64_chr4_seg100000_segment11 as recorded/done in computeAcc: 0.389026 , based on nr of corr 38903, tot cnt 100000
# Acc at R64_chr4_seg100000_segment11 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment12_avgRevCompl0_win1_step1
# 12 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment12: 0.387646 based on corr 38765 and tot 100000
# Acc at R64_chr4_seg100000_segment12 as recorded/done in computeAcc: 0.387646 , based on nr of corr 38765, tot cnt 100000
# Acc at R64_chr4_seg100000_segment12 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment13_avgRevCompl0_win1_step1
# 13 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment13: 0.386616 based on corr 38662 and tot 100000
# Acc at R64_chr4_seg100000_segment13 as recorded/done in computeAcc: 0.386616 , based on nr of corr 38662, tot cnt 100000
# Acc at R64_chr4_seg100000_segment13 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment14_avgRevCompl0_win1_step1
# 14 (100000,)
# 100000
# 100000
# Acc at R64_chr4_seg100000_segment14: 0.388896 based on corr 38890 and tot 100000
# Acc at R64_chr4_seg100000_segment14 as recorded/done in computeAcc: 0.388896 , based on nr of corr 38890, tot cnt 100000
# Acc at R64_chr4_seg100000_segment14 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr4_seg100000_segment15_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr5_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr5_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr5_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr5_seg100000_segment0: 0.377645 based on corr 37746 and tot 99950
# Acc at R64_chr5_seg100000_segment0 as recorded/done in computeAcc: 0.377645 , based on nr of corr 37746, tot cnt 99950
# Acc at R64_chr5_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr5_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr5_seg100000_segment1: 0.384416 based on corr 38442 and tot 100000
# Acc at R64_chr5_seg100000_segment1 as recorded/done in computeAcc: 0.384416 , based on nr of corr 38442, tot cnt 100000
# Acc at R64_chr5_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr5_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr5_seg100000_segment2: 0.383786 based on corr 38379 and tot 100000
# Acc at R64_chr5_seg100000_segment2 as recorded/done in computeAcc: 0.383786 , based on nr of corr 38379, tot cnt 100000
# Acc at R64_chr5_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr5_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr5_seg100000_segment3: 0.387906 based on corr 38791 and tot 100000
# Acc at R64_chr5_seg100000_segment3 as recorded/done in computeAcc: 0.387906 , based on nr of corr 38791, tot cnt 100000
# Acc at R64_chr5_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr5_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# 100000
# Acc at R64_chr5_seg100000_segment4: 0.381386 based on corr 38139 and tot 100000
# Acc at R64_chr5_seg100000_segment4 as recorded/done in computeAcc: 0.381386 , based on nr of corr 38139, tot cnt 100000
# Acc at R64_chr5_seg100000_segment4 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr5_seg100000_segment5_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr6_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr6_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr6_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr6_seg100000_segment0: 0.379116 based on corr 37893 and tot 99950
# Acc at R64_chr6_seg100000_segment0 as recorded/done in computeAcc: 0.379116 , based on nr of corr 37893, tot cnt 99950
# Acc at R64_chr6_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr6_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr6_seg100000_segment1: 0.389236 based on corr 38924 and tot 100000
# Acc at R64_chr6_seg100000_segment1 as recorded/done in computeAcc: 0.389236 , based on nr of corr 38924, tot cnt 100000
# Acc at R64_chr6_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr6_seg100000_segment2_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr7_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr7_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr7_seg100000_segment0: 0.387860 based on corr 38767 and tot 99950
# Acc at R64_chr7_seg100000_segment0 as recorded/done in computeAcc: 0.387860 , based on nr of corr 38767, tot cnt 99950
# Acc at R64_chr7_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr7_seg100000_segment1: 0.387836 based on corr 38784 and tot 100000
# Acc at R64_chr7_seg100000_segment1 as recorded/done in computeAcc: 0.387836 , based on nr of corr 38784, tot cnt 100000
# Acc at R64_chr7_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr7_seg100000_segment2: 0.383426 based on corr 38343 and tot 100000
# Acc at R64_chr7_seg100000_segment2 as recorded/done in computeAcc: 0.383426 , based on nr of corr 38343, tot cnt 100000
# Acc at R64_chr7_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr7_seg100000_segment3: 0.388216 based on corr 38822 and tot 100000
# Acc at R64_chr7_seg100000_segment3 as recorded/done in computeAcc: 0.388216 , based on nr of corr 38822, tot cnt 100000
# Acc at R64_chr7_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# 100000
# Acc at R64_chr7_seg100000_segment4: 0.390146 based on corr 39015 and tot 100000
# Acc at R64_chr7_seg100000_segment4 as recorded/done in computeAcc: 0.390146 , based on nr of corr 39015, tot cnt 100000
# Acc at R64_chr7_seg100000_segment4 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# 100000
# Acc at R64_chr7_seg100000_segment5: 0.378496 based on corr 37850 and tot 100000
# Acc at R64_chr7_seg100000_segment5 as recorded/done in computeAcc: 0.378496 , based on nr of corr 37850, tot cnt 100000
# Acc at R64_chr7_seg100000_segment5 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# 100000
# Acc at R64_chr7_seg100000_segment6: 0.391536 based on corr 39154 and tot 100000
# Acc at R64_chr7_seg100000_segment6 as recorded/done in computeAcc: 0.391536 , based on nr of corr 39154, tot cnt 100000
# Acc at R64_chr7_seg100000_segment6 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment7_avgRevCompl0_win1_step1
# 7 (100000,)
# 100000
# 100000
# Acc at R64_chr7_seg100000_segment7: 0.385836 based on corr 38584 and tot 100000
# Acc at R64_chr7_seg100000_segment7 as recorded/done in computeAcc: 0.385836 , based on nr of corr 38584, tot cnt 100000
# Acc at R64_chr7_seg100000_segment7 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment8_avgRevCompl0_win1_step1
# 8 (100000,)
# 100000
# 100000
# Acc at R64_chr7_seg100000_segment8: 0.391806 based on corr 39181 and tot 100000
# Acc at R64_chr7_seg100000_segment8 as recorded/done in computeAcc: 0.391806 , based on nr of corr 39181, tot cnt 100000
# Acc at R64_chr7_seg100000_segment8 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment9_avgRevCompl0_win1_step1
# 9 (100000,)
# 100000
# 100000
# Acc at R64_chr7_seg100000_segment9: 0.384856 based on corr 38486 and tot 100000
# Acc at R64_chr7_seg100000_segment9 as recorded/done in computeAcc: 0.384856 , based on nr of corr 38486, tot cnt 100000
# Acc at R64_chr7_seg100000_segment9 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr7_seg100000_segment10_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr8_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr8_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr8/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr8_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr8_seg100000_segment0: 0.378806 based on corr 37862 and tot 99950
# Acc at R64_chr8_seg100000_segment0 as recorded/done in computeAcc: 0.378806 , based on nr of corr 37862, tot cnt 99950
# Acc at R64_chr8_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr8/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr8_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr8_seg100000_segment1: 0.384426 based on corr 38443 and tot 100000
# Acc at R64_chr8_seg100000_segment1 as recorded/done in computeAcc: 0.384426 , based on nr of corr 38443, tot cnt 100000
# Acc at R64_chr8_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr8/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr8_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr8_seg100000_segment2: 0.387446 based on corr 38745 and tot 100000
# Acc at R64_chr8_seg100000_segment2 as recorded/done in computeAcc: 0.387446 , based on nr of corr 38745, tot cnt 100000
# Acc at R64_chr8_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr8/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr8_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr8_seg100000_segment3: 0.381166 based on corr 38117 and tot 100000
# Acc at R64_chr8_seg100000_segment3 as recorded/done in computeAcc: 0.381166 , based on nr of corr 38117, tot cnt 100000
# Acc at R64_chr8_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr8/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr8_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# 100000
# Acc at R64_chr8_seg100000_segment4: 0.381926 based on corr 38193 and tot 100000
# Acc at R64_chr8_seg100000_segment4 as recorded/done in computeAcc: 0.381926 , based on nr of corr 38193, tot cnt 100000
# Acc at R64_chr8_seg100000_segment4 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr8/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr8_seg100000_segment5_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr9_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr9_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr9/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr9_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr9_seg100000_segment0: 0.383798 based on corr 38361 and tot 99950
# Acc at R64_chr9_seg100000_segment0 as recorded/done in computeAcc: 0.383798 , based on nr of corr 38361, tot cnt 99950
# Acc at R64_chr9_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr9/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr9_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr9_seg100000_segment1: 0.390476 based on corr 39048 and tot 100000
# Acc at R64_chr9_seg100000_segment1 as recorded/done in computeAcc: 0.390476 , based on nr of corr 39048, tot cnt 100000
# Acc at R64_chr9_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr9/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr9_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr9_seg100000_segment2: 0.383386 based on corr 38339 and tot 100000
# Acc at R64_chr9_seg100000_segment2 as recorded/done in computeAcc: 0.383386 , based on nr of corr 38339, tot cnt 100000
# Acc at R64_chr9_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr9/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr9_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr9_seg100000_segment3: 0.378906 based on corr 37891 and tot 100000
# Acc at R64_chr9_seg100000_segment3 as recorded/done in computeAcc: 0.378906 , based on nr of corr 37891, tot cnt 100000
# Acc at R64_chr9_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr9/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr9_seg100000_segment4_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr10_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr10_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr10/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr10_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr10_seg100000_segment0: 0.378856 based on corr 37867 and tot 99950
# Acc at R64_chr10_seg100000_segment0 as recorded/done in computeAcc: 0.378856 , based on nr of corr 37867, tot cnt 99950
# Acc at R64_chr10_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr10/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr10_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr10_seg100000_segment1: 0.386196 based on corr 38620 and tot 100000
# Acc at R64_chr10_seg100000_segment1 as recorded/done in computeAcc: 0.386196 , based on nr of corr 38620, tot cnt 100000
# Acc at R64_chr10_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr10/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr10_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr10_seg100000_segment2: 0.385086 based on corr 38509 and tot 100000
# Acc at R64_chr10_seg100000_segment2 as recorded/done in computeAcc: 0.385086 , based on nr of corr 38509, tot cnt 100000
# Acc at R64_chr10_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr10/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr10_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr10_seg100000_segment3: 0.387646 based on corr 38765 and tot 100000
# Acc at R64_chr10_seg100000_segment3 as recorded/done in computeAcc: 0.387646 , based on nr of corr 38765, tot cnt 100000
# Acc at R64_chr10_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr10/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr10_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# 100000
# Acc at R64_chr10_seg100000_segment4: 0.381926 based on corr 38193 and tot 100000
# Acc at R64_chr10_seg100000_segment4 as recorded/done in computeAcc: 0.381926 , based on nr of corr 38193, tot cnt 100000
# Acc at R64_chr10_seg100000_segment4 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr10/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr10_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# 100000
# Acc at R64_chr10_seg100000_segment5: 0.384726 based on corr 38473 and tot 100000
# Acc at R64_chr10_seg100000_segment5 as recorded/done in computeAcc: 0.384726 , based on nr of corr 38473, tot cnt 100000
# Acc at R64_chr10_seg100000_segment5 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr10/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr10_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# 100000
# Acc at R64_chr10_seg100000_segment6: 0.385846 based on corr 38585 and tot 100000
# Acc at R64_chr10_seg100000_segment6 as recorded/done in computeAcc: 0.385846 , based on nr of corr 38585, tot cnt 100000
# Acc at R64_chr10_seg100000_segment6 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr10/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr10_seg100000_segment7_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr11_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr11_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr11/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr11_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr11_seg100000_segment0: 0.376304 based on corr 37612 and tot 99950
# Acc at R64_chr11_seg100000_segment0 as recorded/done in computeAcc: 0.376304 , based on nr of corr 37612, tot cnt 99950
# Acc at R64_chr11_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr11/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr11_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr11_seg100000_segment1: 0.389886 based on corr 38989 and tot 100000
# Acc at R64_chr11_seg100000_segment1 as recorded/done in computeAcc: 0.389886 , based on nr of corr 38989, tot cnt 100000
# Acc at R64_chr11_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr11/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr11_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr11_seg100000_segment2: 0.389616 based on corr 38962 and tot 100000
# Acc at R64_chr11_seg100000_segment2 as recorded/done in computeAcc: 0.389616 , based on nr of corr 38962, tot cnt 100000
# Acc at R64_chr11_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr11/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr11_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr11_seg100000_segment3: 0.388416 based on corr 38842 and tot 100000
# Acc at R64_chr11_seg100000_segment3 as recorded/done in computeAcc: 0.388416 , based on nr of corr 38842, tot cnt 100000
# Acc at R64_chr11_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr11/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr11_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# 100000
# Acc at R64_chr11_seg100000_segment4: 0.389526 based on corr 38953 and tot 100000
# Acc at R64_chr11_seg100000_segment4 as recorded/done in computeAcc: 0.389526 , based on nr of corr 38953, tot cnt 100000
# Acc at R64_chr11_seg100000_segment4 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr11/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr11_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# 100000
# Acc at R64_chr11_seg100000_segment5: 0.386916 based on corr 38692 and tot 100000
# Acc at R64_chr11_seg100000_segment5 as recorded/done in computeAcc: 0.386916 , based on nr of corr 38692, tot cnt 100000
# Acc at R64_chr11_seg100000_segment5 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr11/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr11_seg100000_segment6_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr12_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr12_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr12/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr12_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr12_seg100000_segment0: 0.378676 based on corr 37849 and tot 99950
# Acc at R64_chr12_seg100000_segment0 as recorded/done in computeAcc: 0.378676 , based on nr of corr 37849, tot cnt 99950
# Acc at R64_chr12_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr12/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr12_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr12_seg100000_segment1: 0.386606 based on corr 38661 and tot 100000
# Acc at R64_chr12_seg100000_segment1 as recorded/done in computeAcc: 0.386606 , based on nr of corr 38661, tot cnt 100000
# Acc at R64_chr12_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr12/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr12_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr12_seg100000_segment2: 0.387226 based on corr 38723 and tot 100000
# Acc at R64_chr12_seg100000_segment2 as recorded/done in computeAcc: 0.387226 , based on nr of corr 38723, tot cnt 100000
# Acc at R64_chr12_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr12/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr12_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr12_seg100000_segment3: 0.382406 based on corr 38241 and tot 100000
# Acc at R64_chr12_seg100000_segment3 as recorded/done in computeAcc: 0.382406 , based on nr of corr 38241, tot cnt 100000
# Acc at R64_chr12_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# ...
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr14_seg100000_segment1: 0.384036 based on corr 38404 and tot 100000
# Acc at R64_chr14_seg100000_segment1 as recorded/done in computeAcc: 0.384036 , based on nr of corr 38404, tot cnt 100000
# Acc at R64_chr14_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr14/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr14_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr14_seg100000_segment2: 0.393726 based on corr 39373 and tot 100000
# Acc at R64_chr14_seg100000_segment2 as recorded/done in computeAcc: 0.393726 , based on nr of corr 39373, tot cnt 100000
# Acc at R64_chr14_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr14/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr14_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr14_seg100000_segment3: 0.385056 based on corr 38506 and tot 100000
# Acc at R64_chr14_seg100000_segment3 as recorded/done in computeAcc: 0.385056 , based on nr of corr 38506, tot cnt 100000
# Acc at R64_chr14_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr14/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr14_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# 100000
# Acc at R64_chr14_seg100000_segment4: 0.386556 based on corr 38656 and tot 100000
# Acc at R64_chr14_seg100000_segment4 as recorded/done in computeAcc: 0.386556 , based on nr of corr 38656, tot cnt 100000
# Acc at R64_chr14_seg100000_segment4 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr14/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr14_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# 100000
# Acc at R64_chr14_seg100000_segment5: 0.381796 based on corr 38180 and tot 100000
# Acc at R64_chr14_seg100000_segment5 as recorded/done in computeAcc: 0.381796 , based on nr of corr 38180, tot cnt 100000
# Acc at R64_chr14_seg100000_segment5 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr14/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr14_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# 100000
# Acc at R64_chr14_seg100000_segment6: 0.381286 based on corr 38129 and tot 100000
# Acc at R64_chr14_seg100000_segment6 as recorded/done in computeAcc: 0.381286 , based on nr of corr 38129, tot cnt 100000
# Acc at R64_chr14_seg100000_segment6 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr14/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr14_seg100000_segment7_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr15_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr15_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr15_seg100000_segment0: 0.375964 based on corr 37578 and tot 99950
# Acc at R64_chr15_seg100000_segment0 as recorded/done in computeAcc: 0.375964 , based on nr of corr 37578, tot cnt 99950
# Acc at R64_chr15_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr15_seg100000_segment1: 0.385546 based on corr 38555 and tot 100000
# Acc at R64_chr15_seg100000_segment1 as recorded/done in computeAcc: 0.385546 , based on nr of corr 38555, tot cnt 100000
# Acc at R64_chr15_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr15_seg100000_segment2: 0.384116 based on corr 38412 and tot 100000
# Acc at R64_chr15_seg100000_segment2 as recorded/done in computeAcc: 0.384116 , based on nr of corr 38412, tot cnt 100000
# Acc at R64_chr15_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr15_seg100000_segment3: 0.383196 based on corr 38320 and tot 100000
# Acc at R64_chr15_seg100000_segment3 as recorded/done in computeAcc: 0.383196 , based on nr of corr 38320, tot cnt 100000
# Acc at R64_chr15_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# 100000
# Acc at R64_chr15_seg100000_segment4: 0.385536 based on corr 38554 and tot 100000
# Acc at R64_chr15_seg100000_segment4 as recorded/done in computeAcc: 0.385536 , based on nr of corr 38554, tot cnt 100000
# Acc at R64_chr15_seg100000_segment4 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# 100000
# Acc at R64_chr15_seg100000_segment5: 0.386586 based on corr 38659 and tot 100000
# Acc at R64_chr15_seg100000_segment5 as recorded/done in computeAcc: 0.386586 , based on nr of corr 38659, tot cnt 100000
# Acc at R64_chr15_seg100000_segment5 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# 100000
# Acc at R64_chr15_seg100000_segment6: 0.386956 based on corr 38696 and tot 100000
# Acc at R64_chr15_seg100000_segment6 as recorded/done in computeAcc: 0.386956 , based on nr of corr 38696, tot cnt 100000
# Acc at R64_chr15_seg100000_segment6 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment7_avgRevCompl0_win1_step1
# 7 (100000,)
# 100000
# 100000
# Acc at R64_chr15_seg100000_segment7: 0.390046 based on corr 39005 and tot 100000
# Acc at R64_chr15_seg100000_segment7 as recorded/done in computeAcc: 0.390046 , based on nr of corr 39005, tot cnt 100000
# Acc at R64_chr15_seg100000_segment7 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment8_avgRevCompl0_win1_step1
# 8 (100000,)
# 100000
# 100000
# Acc at R64_chr15_seg100000_segment8: 0.385636 based on corr 38564 and tot 100000
# Acc at R64_chr15_seg100000_segment8 as recorded/done in computeAcc: 0.385636 , based on nr of corr 38564, tot cnt 100000
# Acc at R64_chr15_seg100000_segment8 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment9_avgRevCompl0_win1_step1
# 9 (100000,)
# 100000
# 100000
# Acc at R64_chr15_seg100000_segment9: 0.382356 based on corr 38236 and tot 100000
# Acc at R64_chr15_seg100000_segment9 as recorded/done in computeAcc: 0.382356 , based on nr of corr 38236, tot cnt 100000
# Acc at R64_chr15_seg100000_segment9 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr15_seg100000_segment10_avgRevCompl0_win1_step1
# /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr16_annotationArray_simpleRepeats
# Annotation file /content/drive/MyDrive/DNA_proj/data/S288C_reference_genome_R64-1-1_20110203/R64_chr16_annotationArray_simpleRepeats not found
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr16_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# 99950
# Acc at R64_chr16_seg100000_segment0: 0.378515 based on corr 37833 and tot 99950
# Acc at R64_chr16_seg100000_segment0 as recorded/done in computeAcc: 0.378515 , based on nr of corr 37833, tot cnt 99950
# Acc at R64_chr16_seg100000_segment0 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr16_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# 100000
# Acc at R64_chr16_seg100000_segment1: 0.398816 based on corr 39882 and tot 100000
# Acc at R64_chr16_seg100000_segment1 as recorded/done in computeAcc: 0.398816 , based on nr of corr 39882, tot cnt 100000
# Acc at R64_chr16_seg100000_segment1 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr16_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# 100000
# Acc at R64_chr16_seg100000_segment2: 0.380866 based on corr 38087 and tot 100000
# Acc at R64_chr16_seg100000_segment2 as recorded/done in computeAcc: 0.380866 , based on nr of corr 38087, tot cnt 100000
# Acc at R64_chr16_seg100000_segment2 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr16_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# 100000
# Acc at R64_chr16_seg100000_segment3: 0.389606 based on corr 38961 and tot 100000
# Acc at R64_chr16_seg100000_segment3 as recorded/done in computeAcc: 0.389606 , based on nr of corr 38961, tot cnt 100000
# Acc at R64_chr16_seg100000_segment3 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr16_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# 100000
# Acc at R64_chr16_seg100000_segment4: 0.388536 based on corr 38854 and tot 100000
# Acc at R64_chr16_seg100000_segment4 as recorded/done in computeAcc: 0.388536 , based on nr of corr 38854, tot cnt 100000
# Acc at R64_chr16_seg100000_segment4 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr16_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# 100000
# Acc at R64_chr16_seg100000_segment5: 0.382736 based on corr 38274 and tot 100000
# Acc at R64_chr16_seg100000_segment5 as recorded/done in computeAcc: 0.382736 , based on nr of corr 38274, tot cnt 100000
# Acc at R64_chr16_seg100000_segment5 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr16_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# 100000
# Acc at R64_chr16_seg100000_segment6: 0.383846 based on corr 38385 and tot 100000
# Acc at R64_chr16_seg100000_segment6 as recorded/done in computeAcc: 0.383846 , based on nr of corr 38385, tot cnt 100000
# Acc at R64_chr16_seg100000_segment6 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr16_seg100000_segment7_avgRevCompl0_win1_step1
# 7 (100000,)
# 100000
# 100000
# Acc at R64_chr16_seg100000_segment7: 0.383336 based on corr 38334 and tot 100000
# Acc at R64_chr16_seg100000_segment7 as recorded/done in computeAcc: 0.383336 , based on nr of corr 38334, tot cnt 100000
# Acc at R64_chr16_seg100000_segment7 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr16_seg100000_segment8_avgRevCompl0_win1_step1
# 8 (100000,)
# 100000
# 100000
# Acc at R64_chr16_seg100000_segment8: 0.384976 based on corr 38498 and tot 100000
# Acc at R64_chr16_seg100000_segment8 as recorded/done in computeAcc: 0.384976 , based on nr of corr 38498, tot cnt 100000
# Acc at R64_chr16_seg100000_segment8 for repeats as recorded/done in computeAcc: 0.000000 , based on nr of corr 0, tot cnt 0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predReturn_R64_chr16_seg100000_segment9_avgRevCompl0_win1_step1

# %% [markdown]
# We can then aggregate the results per chromosome and get the results in a table (in .txt and Latex format too) and in a plot:

# %%
#Do the aggregation so that it covers all chromosomes/anotations for which results are had:
dictionaryName = 'accuracyChromoByAnnoDictionary'
stats.calculateAggrAccOnChromos(rootOutput =rootOutput , chromosomeDict= chromosomeDict,  dictionaryName = dictionaryName)

# %%
#Yeast, w. train test split
rootResults = rootOutput
captionText = 'LSTM50 on R64'

import pickle

#Results per chromo/anno
loadFile = rootResults + 'accuracyByChromoAnnoDictionary' 
resultsDictChromo = pickle.load(open( loadFile, "rb"))

#Aggr over all chromos
loadFile = rootResults + 'accuracyByAnnoDictionary' 
resultsDict = pickle.load(open( loadFile, "rb"))

fileName = 'table_chromo_anno.txt'
rowNames = chromosomeOrderList
colNames = ['all']   #the models will appear in columns in this order
#with final aggregation row:
stats.makeTexTable(inputDict = resultsDictChromo , rowColHeading = 'chr/annotation', rowNames = rowNames,
                                  columnNames = colNames, inputDict2 = resultsDict, captionText = captionText, rootOutput = rootOutput, fileName = fileName )
# Out:
# ('\\begin{table}[h!]\n  \\begin{center}\n    \\label{tab:table1c}\n    \\begin{tabular}{l | c | c | r} % <-- Alignments: 1st column left, 2nd middle and 3rd right, with vertical lines in between\n      \\textbf{chr/annotation}& \\textbf{all}\\\\\n      \\hline\nR64_chr1 & 0.3852\\\\\nR64_chr2 & 0.386\\\\\nR64_chr3 & 0.3834\\\\\nR64_chr4 & 0.3884\\\\\nR64_chr5 & 0.383\\\\\nR64_chr6 & 0.3842\\\\\nR64_chr7 & 0.387\\\\\nR64_chr8 & 0.3828\\\\\nR64_chr9 & 0.3841\\\\\nR64_chr10 & 0.3843\\\\\nR64_chr11 & 0.3868\\\\\nR64_chr12 & 0.3839\\\\\nR64_chr13 & 0.3871\\\\\nR64_chr14 & 0.3838\\\\\nR64_chr15 & 0.3846\\\\\nR64_chr16 & 0.3857\\\\\nAll & 0.3855\\\\\n    \\end{tabular}\n        \\caption{LSTM50 on R64}\n  \\end{center}\n \\end{table}',
#  ['all'])

# %%
chromosomeOrderList = chromosomeOrderList[::-1]
saveAtDpi = 300
addAvg_b = 1
avgLevel = 0.3751
resultsDictByChromoModel = stats.collectAccuracyChromosomesSeveralModels(rootOutput = rootOutput, 
                                  rootPredictModelList = [rootOutput], 
                                  modelFileList = [modelFileNameNN],
                                  modelNameList = ['LSTM4'],
                                  chromosomeOrderList = chromosomeOrderList,
                                  plot_b = 1,
                                  addAvg_b = addAvg_b,
                                  avgLevel = avgLevel,
                                  saveAtDpi = saveAtDpi)
# Out:
# {'R64_chr1': {'all': [0.3851912978244561, 77019.0, 199950]}, 'R64_chr2': {'all': [0.38597787361710106, 308763.0, 799950]}, 'R64_chr3': {'all': [0.3834405734289048, 115013.0, 299950]}, 'R64_chr4': {'all': [0.38844094803160106, 582642.0, 1499950]}, 'R64_chr5': {'all': [0.38303230323032306, 191497.0, 499950]}, 'R64_chr6': {'all': [0.3841810452613153, 76817.0, 199950]}, 'R64_chr7': {'all': [0.38700535026751337, 386986.0, 999950]}, 'R64_chr8': {'all': [0.38275827582758276, 191360.0, 499950]}, 'R64_chr9': {'all': [0.3841455181897737, 153639.0, 399950]}, 'R64_chr10': {'all': [0.3843303093078077, 269012.0, 699950]}, 'R64_chr11': {'all': [0.38678223185265437, 232050.0, 599950]}, 'R64_chr12': {'all': [0.38388919445972297, 383870.0, 999950]}, 'R64_chr13': {'all': [0.38711261736763153, 348382.0, 899950]}, 'R64_chr14': {'all': [0.38375312522323024, 268608.0, 699950]}, 'R64_chr15': {'all': [0.38459822991149556, 384579.0, 999950]}, 'R64_chr16': {'all': [0.3856969831657314, 347108.0, 899950]}}
# nChromos  16

# %% [markdown]
# Running the Fourier transforms on the model's probability arrays (prob of reference base at each position) is done in a single call to a wrapper. First some settings, and then the call (it runs surprisingly fast):

# %%
rootOutput =  r"/content/drive/MyDrive/DNA_proj/results/predictions/"

#We reuse some of the settings from above
modelFileNameNN = modelFileNameNN
chromosomeOrderList = chromosomeOrderList
chromosomeDict = chromosomeDict 

#placeholders
modelFileName_forATorGCbias = ''
rootOutput_forATorGCbias = ''
rootInput_forATorGCbias = ''
forATorGCbias_b = 0 #!

#General settings:
segmentLength = 100000

augmentWithRevComplementary_b = 0  #!

#window lgth and stepsize used in generating the avg prediction
windowLength = 1
stepSize = 1
                      
#Param's for Fourier plots:
shuffle_b = 0 #!
randomizeDisqualified_b = 0 #!
randomizingByShuffle_b = 0 #!
fullGC_b = 0 #!

#Which input to use:
inputArrayType = 1 # 1: ref base prob's; 0: pred returns
plotOnlyNorm_b = 1 #default:1 

#Here we only plot the 20-2000 range; extend the list with more starts/stops to cover several ranges
fourierStep = 10
fourierRawPlotFrq = 5
fourierStartList = [20]
fourierStopList = [2000]
fourierWindowLengthList = [100]

ratioQcutoff = 0.9 #0.7 w hg18
dumpFourier_b = 0
dumpFileNamePrefix = ''

# %%
#Call to Fourier-wrapper:
for i in range(len(fourierStartList)):
    fourierStart = fourierStartList[i]
    fourierStop = fourierStopList[i]
    fourierWindowLength = fourierWindowLengthList[i]
    stats.computeFourierChromosomes(chromosomeOrderList = chromosomeOrderList,
                                    rootOutput = rootOutput,
                                    modelFileName = modelFileNameNN,  
                                    segmentLength = segmentLength,
                                    inputArrayType = inputArrayType,
                                    averageRevComplementary_b = augmentWithRevComplementary_b,
                                    ratioQcutoff = ratioQcutoff,
                                    windowLength = windowLength,
                                    stepSize = stepSize,
                                    plotOnlyNorm_b = plotOnlyNorm_b,
                                    fourierWindowLength = fourierWindowLength,
                                    fourierStart = fourierStart,
                                    fourierStop = fourierStop,
                                    fourierStep = fourierStep, 
                                    fourierRawPlotFrq = fourierRawPlotFrq,
                                    shuffle_b = shuffle_b,
                                    randomizeDisqualified_b =randomizeDisqualified_b,
                                    randomizingByShuffle_b = randomizingByShuffle_b,
                                    forATorGCbias_b = forATorGCbias_b, 
                                    rootOutput_forATorGCbias= rootOutput_forATorGCbias,
                                    rootInput_forATorGCbias = rootInput_forATorGCbias,
                                    fullGC_b = fullGC_b,
                                    dumpFourier_b = dumpFourier_b,
                                    dumpFileNamePrefix = dumpFileNamePrefix, 
                                    modelFileName_forATorGCbias = modelFileName_forATorGCbias)
# Out:
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr1/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr1_seg100000_segment0_avgRevCompl0
# 99950
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 29426.839650 (1.049864)
# After stop (2000) the max (min) modulus of Fourier coeff is: 210.230853 (0.187132)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr1/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr1_seg100000_segment1_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29318.820430 (0.360726)
# After stop (2000) the max (min) modulus of Fourier coeff is: 236.996151 (0.039374)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr1/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr1_seg100000_segment2_avgRevCompl0
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/FourierOnRefBaseProb/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment0_avgRevCompl0
# 99950
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 29238.289271 (1.090319)
# After stop (2000) the max (min) modulus of Fourier coeff is: 191.145671 (0.227573)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment1_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29530.853347 (1.948767)
# After stop (2000) the max (min) modulus of Fourier coeff is: 197.694144 (0.069005)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment2_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29073.469150 (2.761018)
# After stop (2000) the max (min) modulus of Fourier coeff is: 156.258643 (0.164225)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment3_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29382.304674 (0.957062)
# After stop (2000) the max (min) modulus of Fourier coeff is: 139.777304 (0.169242)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment4_avgRevCompl0
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29697.831064 (1.643515)
# After stop (2000) the max (min) modulus of Fourier coeff is: 209.900434 (0.119637)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment5_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29271.045999 (0.305688)
# After stop (2000) the max (min) modulus of Fourier coeff is: 161.698544 (0.021876)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment6_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29230.293078 (0.705434)
# After stop (2000) the max (min) modulus of Fourier coeff is: 141.075621 (0.061374)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment7_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29160.384917 (0.375086)
# After stop (2000) the max (min) modulus of Fourier coeff is: 181.606134 (0.139173)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment8_avgRevCompl0
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/FourierOnRefBaseProb/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr3_seg100000_segment0_avgRevCompl0
# 99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 29416.182640 (0.740562)
# After stop (2000) the max (min) modulus of Fourier coeff is: 166.824541 (0.195305)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr3_seg100000_segment1_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29090.580511 (0.892642)
# After stop (2000) the max (min) modulus of Fourier coeff is: 152.500331 (0.212665)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr3_seg100000_segment2_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29329.501045 (1.741137)
# After stop (2000) the max (min) modulus of Fourier coeff is: 216.171316 (0.182436)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr3_seg100000_segment3_avgRevCompl0
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/FourierOnRefBaseProb/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment0_avgRevCompl0
# 99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 29052.058680 (0.986998)
# After stop (2000) the max (min) modulus of Fourier coeff is: 130.222999 (0.095254)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment1_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29590.387126 (0.430683)
# After stop (2000) the max (min) modulus of Fourier coeff is: 186.933494 (0.131328)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment2_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29358.292179 (1.585267)
# After stop (2000) the max (min) modulus of Fourier coeff is: 135.545171 (0.179864)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment3_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29759.178336 (0.936540)
# After stop (2000) the max (min) modulus of Fourier coeff is: 254.464148 (0.234641)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment4_avgRevCompl0
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29404.292610 (1.600772)
# After stop (2000) the max (min) modulus of Fourier coeff is: 139.787868 (0.044269)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment5_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29526.141414 (0.511913)
# After stop (2000) the max (min) modulus of Fourier coeff is: 175.181781 (0.140106)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment6_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29313.866862 (2.285492)
# After stop (2000) the max (min) modulus of Fourier coeff is: 182.350272 (0.065309)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment7_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29473.642520 (1.710377)
# After stop (2000) the max (min) modulus of Fourier coeff is: 239.700329 (0.079242)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment8_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29545.120455 (1.293766)
# After stop (2000) the max (min) modulus of Fourier coeff is: 207.421840 (0.230303)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment9_avgRevCompl0
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29265.734605 (1.386578)
# After stop (2000) the max (min) modulus of Fourier coeff is: 154.602397 (0.131552)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment10_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29221.385872 (1.999509)
# After stop (2000) the max (min) modulus of Fourier coeff is: 180.283397 (0.077504)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment11_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29379.597887 (1.615393)
# After stop (2000) the max (min) modulus of Fourier coeff is: 233.639015 (0.235818)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment12_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29426.759939 (1.330783)
# After stop (2000) the max (min) modulus of Fourier coeff is: 153.528469 (0.141222)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment13_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29334.953486 (1.306488)
# After stop (2000) the max (min) modulus of Fourier coeff is: 183.021903 (0.066533)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment14_avgRevCompl0
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29396.891083 (0.993020)
# After stop (2000) the max (min) modulus of Fourier coeff is: 234.877937 (0.004686)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment15_avgRevCompl0
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/FourierOnRefBaseProb/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment0_avgRevCompl0
# 99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 29102.621265 (1.641079)
# After stop (2000) the max (min) modulus of Fourier coeff is: 193.948657 (0.152533)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment1_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29237.631731 (1.361717)
# After stop (2000) the max (min) modulus of Fourier coeff is: 152.503479 (0.058687)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment2_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29279.525364 (0.598714)
# After stop (2000) the max (min) modulus of Fourier coeff is: 194.375809 (0.196587)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment3_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29378.721858 (0.900946)
# After stop (2000) the max (min) modulus of Fourier coeff is: 200.155758 (0.093475)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment4_avgRevCompl0
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29105.743320 (0.795037)
# After stop (2000) the max (min) modulus of Fourier coeff is: 179.534320 (0.093396)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment5_avgRevCompl0
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/FourierOnRefBaseProb/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr6_seg100000_segment0_avgRevCompl0
# 99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 29117.474822 (1.102197)
# After stop (2000) the max (min) modulus of Fourier coeff is: 204.773702 (0.089226)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr6_seg100000_segment1_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29471.030247 (0.183576)
# After stop (2000) the max (min) modulus of Fourier coeff is: 237.127451 (0.127469)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr6_seg100000_segment2_avgRevCompl0
# Directory /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/FourierOnRefBaseProb/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr7_seg100000_segment0_avgRevCompl0
# 99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
# ...
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr15_seg100000_segment6_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29191.676909 (0.564287)
# After stop (2000) the max (min) modulus of Fourier coeff is: 158.144389 (0.047695)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr15_seg100000_segment7_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29477.193800 (0.297428)
# After stop (2000) the max (min) modulus of Fourier coeff is: 149.809221 (0.096138)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr15_seg100000_segment8_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29313.414808 (0.709066)
# After stop (2000) the max (min) modulus of Fourier coeff is: 173.470165 (0.078490)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr15_seg100000_segment9_avgRevCompl0
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29139.058846 (1.109937)
# After stop (2000) the max (min) modulus of Fourier coeff is: 173.394296 (0.069434)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr15_seg100000_segment10_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment0_avgRevCompl0
# 99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 28952.290704 (0.650513)
# After stop (2000) the max (min) modulus of Fourier coeff is: 191.460033 (0.212649)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment1_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29858.577803 (0.727732)
# After stop (2000) the max (min) modulus of Fourier coeff is: 180.458974 (0.124903)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment2_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29122.071718 (1.361520)
# After stop (2000) the max (min) modulus of Fourier coeff is: 163.315573 (0.105481)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment3_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29514.527424 (0.728264)
# After stop (2000) the max (min) modulus of Fourier coeff is: 180.321495 (0.125774)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment4_avgRevCompl0
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29342.472081 (1.194753)
# After stop (2000) the max (min) modulus of Fourier coeff is: 135.979735 (0.027423)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment5_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29186.730451 (1.236069)
# After stop (2000) the max (min) modulus of Fourier coeff is: 164.866802 (0.074335)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment6_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29286.250912 (2.186335)
# After stop (2000) the max (min) modulus of Fourier coeff is: 151.434222 (0.122156)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment7_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29188.159836 (0.223435)
# After stop (2000) the max (min) modulus of Fourier coeff is: 228.138809 (0.113080)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment8_avgRevCompl0
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 29308.605545 (1.630856)
# After stop (2000) the max (min) modulus of Fourier coeff is: 150.616714 (0.132629)
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment9_avgRevCompl0

# %% [markdown]
# You should now be able to find the output plots in  FouriersOnRefBaseProb/20To2000 subfolders of the predictions/chrNN folders.
#
# To run the Fourier on GC content you must first create the GC-indicator arrays for the purpose. This can be done by abusing the code aimed for computing accuracies (by a little 'hack' we arrange it so that the model is always right if the given position holds a G or C, and else it is wrong):

# %%
#This cell is just for the case that we have changed the code and need to reload:
import imp
imp.reload(stats)
# Out:
# <module 'dnaNet_stats_py3' from '/content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py'>

# %%
rootGenome = rootGenome

rootOutput = r"/content/drive/MyDrive/DNA_proj/results/predictions/"
rootModel = r"/content/drive/MyDrive/DNA_proj/results/training/"
lastRepeatNr = nrOfRepeats -1 
modelFileNameNN = "modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr" + str(lastRepeatNr)

rootOutputBias = r"/content/drive/MyDrive/DNA_proj/results/"  

chromosomeOrderList = ['R64_chr1', 'R64_chr2', 'R64_chr3', 'R64_chr4', 'R64_chr5', 'R64_chr6', 'R64_chr7', 'R64_chr8','R64_chr9', 'R64_chr10', 'R64_chr11', 'R64_chr12','R64_chr13', 'R64_chr14', 'R64_chr15', 'R64_chr16']
chromosomeDict = {'R64_chr1':[0,1e8], 'R64_chr2':[0,1e8], 'R64_chr3':[0,1e8], 'R64_chr4':[0,1e8], 'R64_chr5':[0,1e8], 'R64_chr6':[0,1e8], 'R64_chr7':[0,1e8], 'R64_chr8':[0,1e8],'R64_chr9':[0,1e8], 'R64_chr10':[0,1e8], 'R64_chr11':[0,1e8], 'R64_chr12':[0,1e8],'R64_chr13':[0,1e8], 'R64_chr14':[0,1e8], 'R64_chr15':[0,1e8], 'R64_chr16':[0,1e8]}
startAtSegmentDict = {}

# %% [markdown]
# The accuracies (as 'average prediction' or so) that get printed to the screen are the GC%'s .. it takes a little while to run this (a few minutes):

# %%
#set this so that it matches the setting for the computed predArray(s)
segmentLength = 100000
averageRevComplementary_b = 0

#set these as desired
windowLength = 1
stepSize = 1
Fourier_b = 0
on_binf_b = 1
defaultAccuracy = 0.25

#CG bias, little 'hack':
forATorGCbias_b = 1 #!
recodeA = [0,0,0,0]
recodeC = [1,1,1,1]
recodeG = [1,1,1,1]
recodeT = [0,0,0,0] 
modelFileName_forATorGCbias ="GCbias"
rootOutput_forATorGCbias  = rootOutputBias + r"GCbias/"

stats.computeAccuracyOnChromosomes(rootGenome = rootGenome, 
                         chromosomeDict = chromosomeDict,
                         chromosomeOrderList = chromosomeOrderList, 
                         rootOutput = rootOutput,
                         rootModel = rootModel,
                         modelFileName = modelFileNameNN,
                        segmentLength = segmentLength,
                        startAtSegmentDict = startAtSegmentDict,
                        averageRevComplementary_b = averageRevComplementary_b, #!!!!!
                        windowLength = windowLength,
                        stepSize = stepSize,
                        Fourier_b = Fourier_b,
                        defaultAccuracy = defaultAccuracy,
                        on_binf_b = on_binf_b,
                        forATorGCbias_b = forATorGCbias_b, 
                        rootOutput_forATorGCbias= rootOutput_forATorGCbias,
                        modelFileName_forATorGCbias = modelFileName_forATorGCbias,
                        recodeA = recodeA,
                             recodeC = recodeC,
                             recodeG = recodeG,
                             recodeT = recodeT
                             )
# Out:
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]
#
# Found data for this chromosome: ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]
# 60 60 60
# [['ref|NC_001133| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=I]', 230218]]
# []
# Length of genome sequence read in:230218
# Length of exonic-info sequence read in:230218
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:230218
# Of these 0 are W's
# Length genome sequence, only ACGT's:230218
# I'm doing a forATorGCbias run!
# nrSegments:  2
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr1/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr1_seg100000_segment0_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr1/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr1_seg100000_segment0_avgRevCompl0
# lSamples  99950 , nrSteps  99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 39135 , cntTot: 99950 ; average prediction acc : 0.391546
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.391546
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr1/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr1_seg100000_segment1_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr1/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr1_seg100000_segment1_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 39455 , cntTot: 100000 ; average prediction acc : 0.394550
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.394550
# No repeat sections were recorded in the genome data.
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]
#
# Found data for this chromosome: ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]
# 60 60 60
# [['ref|NC_001134| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=II]', 813184]]
# []
# Length of genome sequence read in:813184
# Length of exonic-info sequence read in:813184
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:813184
# Of these 0 are W's
# Length genome sequence, only ACGT's:813184
# I'm doing a forATorGCbias run!
# nrSegments:  8
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr2_seg100000_segment0_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment0_avgRevCompl0
# lSamples  99950 , nrSteps  99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38526 , cntTot: 99950 ; average prediction acc : 0.385453
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385453
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr2_seg100000_segment1_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment1_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38442 , cntTot: 100000 ; average prediction acc : 0.384420
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384420
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr2_seg100000_segment2_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment2_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38137 , cntTot: 100000 ; average prediction acc : 0.381370
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381370
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr2_seg100000_segment3_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment3_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37965 , cntTot: 100000 ; average prediction acc : 0.379650
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.379650
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr2_seg100000_segment4_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment4_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38670 , cntTot: 100000 ; average prediction acc : 0.386700
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.386700
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr2_seg100000_segment5_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment5_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37394 , cntTot: 100000 ; average prediction acc : 0.373940
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.373940
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr2_seg100000_segment6_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment6_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 39083 , cntTot: 100000 ; average prediction acc : 0.390830
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.390830
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr2_seg100000_segment7_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr2/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr2_seg100000_segment7_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38455 , cntTot: 100000 ; average prediction acc : 0.384550
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384550
# No repeat sections were recorded in the genome data.
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]
#
# Found data for this chromosome: ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]
# 60 60 60
# [['ref|NC_001135| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=III]', 316620]]
# []
# Length of genome sequence read in:316620
# Length of exonic-info sequence read in:316620
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:316620
# Of these 0 are W's
# Length genome sequence, only ACGT's:316620
# I'm doing a forATorGCbias run!
# nrSegments:  3
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr3_seg100000_segment0_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr3_seg100000_segment0_avgRevCompl0
# lSamples  99950 , nrSteps  99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 39102 , cntTot: 99950 ; average prediction acc : 0.391216
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.391216
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr3_seg100000_segment1_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr3_seg100000_segment1_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37197 , cntTot: 100000 ; average prediction acc : 0.371970
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.371970
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr3_seg100000_segment2_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr3/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr3_seg100000_segment2_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 39289 , cntTot: 100000 ; average prediction acc : 0.392890
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.392890
# No repeat sections were recorded in the genome data.
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]
#
# Found data for this chromosome: ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]
# 60 60 60
# [['ref|NC_001136| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=IV]', 1531933]]
# []
# Length of genome sequence read in:1531933
# Length of exonic-info sequence read in:1531933
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:1531933
# Of these 0 are W's
# Length genome sequence, only ACGT's:1531933
# I'm doing a forATorGCbias run!
# nrSegments:  15
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment0_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment0_avgRevCompl0
# lSamples  99950 , nrSteps  99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38375 , cntTot: 99950 ; average prediction acc : 0.383942
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383942
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment1_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment1_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38615 , cntTot: 100000 ; average prediction acc : 0.386150
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.386150
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment2_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment2_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38235 , cntTot: 100000 ; average prediction acc : 0.382350
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.382350
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment3_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment3_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38186 , cntTot: 100000 ; average prediction acc : 0.381860
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381860
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment4_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment4_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37698 , cntTot: 100000 ; average prediction acc : 0.376980
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.376980
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment5_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment5_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37472 , cntTot: 100000 ; average prediction acc : 0.374720
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.374720
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment6_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment6_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37508 , cntTot: 100000 ; average prediction acc : 0.375080
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.375080
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment7_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment7_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37631 , cntTot: 100000 ; average prediction acc : 0.376310
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.376310
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment8_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment8_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37892 , cntTot: 100000 ; average prediction acc : 0.378920
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378920
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment9_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment9_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37629 , cntTot: 100000 ; average prediction acc : 0.376290
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.376290
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment10_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment10_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37375 , cntTot: 100000 ; average prediction acc : 0.373750
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.373750
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment11_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment11_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37339 , cntTot: 100000 ; average prediction acc : 0.373390
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.373390
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment12_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment12_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38006 , cntTot: 100000 ; average prediction acc : 0.380060
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.380060
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment13_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment13_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38110 , cntTot: 100000 ; average prediction acc : 0.381100
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381100
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr4_seg100000_segment14_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr4/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr4_seg100000_segment14_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38188 , cntTot: 100000 ; average prediction acc : 0.381880
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381880
# No repeat sections were recorded in the genome data.
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]
#
# Found data for this chromosome: ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]
# 60 60 60
# [['ref|NC_001137| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=V]', 576874]]
# []
# Length of genome sequence read in:576874
# Length of exonic-info sequence read in:576874
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:576874
# Of these 0 are W's
# Length genome sequence, only ACGT's:576874
# I'm doing a forATorGCbias run!
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr5/ created. Output will be placed there.
# nrSegments:  5
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr5_seg100000_segment0_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment0_avgRevCompl0
# lSamples  99950 , nrSteps  99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 39171 , cntTot: 99950 ; average prediction acc : 0.391906
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.391906
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr5_seg100000_segment1_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment1_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37870 , cntTot: 100000 ; average prediction acc : 0.378700
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378700
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr5_seg100000_segment2_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment2_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38470 , cntTot: 100000 ; average prediction acc : 0.384700
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384700
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr5_seg100000_segment3_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment3_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38571 , cntTot: 100000 ; average prediction acc : 0.385710
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.385710
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr5_seg100000_segment4_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr5/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr5_seg100000_segment4_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38311 , cntTot: 100000 ; average prediction acc : 0.383110
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383110
# No repeat sections were recorded in the genome data.
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]
#
# Found data for this chromosome: ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]
# 60 60 60
# [['ref|NC_001138| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VI]', 270161]]
# []
# Length of genome sequence read in:270161
# Length of exonic-info sequence read in:270161
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:270161
# Of these 0 are W's
# Length genome sequence, only ACGT's:270161
# I'm doing a forATorGCbias run!
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr6/ created. Output will be placed there.
# nrSegments:  2
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr6_seg100000_segment0_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr6_seg100000_segment0_avgRevCompl0
# lSamples  99950 , nrSteps  99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 39447 , cntTot: 99950 ; average prediction acc : 0.394667
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.394667
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr6_seg100000_segment1_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr6/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr6_seg100000_segment1_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37861 , cntTot: 100000 ; average prediction acc : 0.378610
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378610
# No repeat sections were recorded in the genome data.
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]
#
# Found data for this chromosome: ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]
# 60 60 60
# [['ref|NC_001139| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=VII]', 1090940]]
# []
# Length of genome sequence read in:1090940
# Length of exonic-info sequence read in:1090940
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:1090940
# Of these 0 are W's
# Length genome sequence, only ACGT's:1090940
# I'm doing a forATorGCbias run!
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr7/ created. Output will be placed there.
# nrSegments:  10
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr7_seg100000_segment0_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr7_seg100000_segment0_avgRevCompl0
# lSamples  99950 , nrSteps  99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37696 , cntTot: 99950 ; average prediction acc : 0.377149
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.377149
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr7_seg100000_segment1_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr7_seg100000_segment1_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38097 , cntTot: 100000 ; average prediction acc : 0.380970
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.380970
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr7_seg100000_segment2_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr7_seg100000_segment2_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37976 , cntTot: 100000 ; average prediction acc : 0.379760
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.379760
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr7_seg100000_segment3_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr7/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr7_seg100000_segment3_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37900 , cntTot: 100000 ; average prediction acc : 0.379000
# ...
# cntCorr: 38306 , cntTot: 100000 ; average prediction acc : 0.383060
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383060
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr15_seg100000_segment5_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr15_seg100000_segment5_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38445 , cntTot: 100000 ; average prediction acc : 0.384450
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.384450
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr15_seg100000_segment6_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr15_seg100000_segment6_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37521 , cntTot: 100000 ; average prediction acc : 0.375210
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.375210
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr15_seg100000_segment7_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr15_seg100000_segment7_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37838 , cntTot: 100000 ; average prediction acc : 0.378380
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378380
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr15_seg100000_segment8_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr15_seg100000_segment8_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37807 , cntTot: 100000 ; average prediction acc : 0.378070
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378070
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr15_seg100000_segment9_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr15/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr15_seg100000_segment9_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38331 , cntTot: 100000 ; average prediction acc : 0.383310
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.383310
# No repeat sections were recorded in the genome data.
# Reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# Fast reading in genome data ...
# Only considering data following fasta header lines (: chromo names
#  for eucaryots) of length < 200
# OBS: no file containing exonic info was provided, so exonic status is set to 0 from 0 - 100000001
# Genome data file 1st line:
#   >ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]
#
# Found data for this chromosome: ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]
# 60 60 60
# [['ref|NC_001148| [org=Saccharomyces cerevisiae] [strain=S288C] [moltype=genomic] [chromosome=XVI]', 948066]]
# []
# Length of genome sequence read in:948066
# Length of exonic-info sequence read in:948066
# ACGTacgt checked 0 tokens
# Length genome sequence, ACGT's and W's:948066
# Of these 0 are W's
# Length genome sequence, only ACGT's:948066
# I'm doing a forATorGCbias run!
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/ created. Output will be placed there.
# nrSegments:  9
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr16_seg100000_segment0_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment0_avgRevCompl0
# lSamples  99950 , nrSteps  99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38689 , cntTot: 99950 ; average prediction acc : 0.387084
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.387084
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr16_seg100000_segment1_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment1_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38260 , cntTot: 100000 ; average prediction acc : 0.382600
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.382600
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr16_seg100000_segment2_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment2_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37720 , cntTot: 100000 ; average prediction acc : 0.377200
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.377200
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr16_seg100000_segment3_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment3_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38117 , cntTot: 100000 ; average prediction acc : 0.381170
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381170
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr16_seg100000_segment4_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment4_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37994 , cntTot: 100000 ; average prediction acc : 0.379940
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.379940
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr16_seg100000_segment5_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment5_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37816 , cntTot: 100000 ; average prediction acc : 0.378160
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.378160
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr16_seg100000_segment6_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment6_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38080 , cntTot: 100000 ; average prediction acc : 0.380800
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.380800
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr16_seg100000_segment7_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment7_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 37524 , cntTot: 100000 ; average prediction acc : 0.375240
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.375240
# No repeat sections were recorded in the genome data.
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_labelArray_R64_chr16_seg100000_segment8_avgRevCompl0
# /content/drive/MyDrive/DNA_proj/results/predictions/R64_chr16/modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr19_predArray_R64_chr16_seg100000_segment8_avgRevCompl0
# lSamples  100000 , nrSteps  100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:5081: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# cntCorr: 38126 , cntTot: 100000 ; average prediction acc : 0.381260
# corrDisq: 0 , cntDisqTot: 0 ; average prediction acc no disq: 0.381260
# No repeat sections were recorded in the genome data.

# %% [markdown]
# Then run the Fourier transforms again on new settings (this is even faster than above):

# %%
#GC bias
#To get the qual arrays from the model-pred run we need:
rootOutput = r"/content/drive/MyDrive/DNA_proj/results/predictions/"
lastRepeatNr = nrOfRepeats -1 
modelFileNameNN = "modelLSTM_1LayerConv2LayerLstm1LayerDense50_flanks50_win4_filters256_stride1_overlap0_dropout00_bigLoopIter0_repeatNr" + str(lastRepeatNr)
#To get the predReturs fo the bias:
modelFileName_forATorGCbias = 'GCbias'
rootOutput_forATorGCbias = r"/content/drive/MyDrive/DNA_proj/results/GCbias/"  
rootInput_forATorGCbias =rootOutput_forATorGCbias
forATorGCbias_b = 1 #!

# %% [markdown]
# These settings are unchanged, except inputArrayType which must be set to 0!:

# %%
#We reuse some of the settings from above
modelFileNameNN = modelFileNameNN
chromosomeOrderList = chromosomeOrderList
chromosomeDict = chromosomeDict 

#General settings:
segmentLength = 100000

augmentWithRevComplementary_b = 0  #!

#window lgth and stepsize used in generating the avg prediction
windowLength = 1
stepSize = 1
                      
#Param's for Fourier plots:
shuffle_b = 0 #!
randomizeDisqualified_b = 0 #!
randomizingByShuffle_b = 0 #!
fullGC_b = 0 #!

#Which input to use:
inputArrayType = 0 # 1: ref base prob's; 0: pred returns (GCbias)
plotOnlyNorm_b = 1 #default:1 

#Here we only plot the 20-2000 range; extend the list with more starts/stops to cover several ranges
fourierStep = 10
fourierRawPlotFrq = 5
fourierStartList = [20]
fourierStopList = [2000]
fourierWindowLengthList = [100]

ratioQcutoff = 0.9 #0.7 w hg18
dumpFourier_b = 0
dumpFileNamePrefix = ''

# %%
#Then call Fourier-wrapper:
for i in range(len(fourierStartList)):
    fourierStart = fourierStartList[i]
    fourierStop = fourierStopList[i]
    fourierWindowLength = fourierWindowLengthList[i]
    stats.computeFourierChromosomes(chromosomeOrderList = chromosomeOrderList,
                                    rootOutput = rootOutput,
                                    modelFileName = modelFileNameNN,  
                                    segmentLength = segmentLength,
                                    inputArrayType = inputArrayType,
                                    averageRevComplementary_b = augmentWithRevComplementary_b,
                                    ratioQcutoff = ratioQcutoff,
                                    windowLength = windowLength,
                                    stepSize = stepSize,
                                    plotOnlyNorm_b = plotOnlyNorm_b,
                                    fourierWindowLength = fourierWindowLength,
                                    fourierStart = fourierStart,
                                    fourierStop = fourierStop,
                                    fourierStep = fourierStep, 
                                    fourierRawPlotFrq = fourierRawPlotFrq,
                                    shuffle_b = shuffle_b,
                                    randomizeDisqualified_b =randomizeDisqualified_b,
                                    randomizingByShuffle_b = randomizingByShuffle_b,
                                    forATorGCbias_b = forATorGCbias_b, 
                                    rootOutput_forATorGCbias= rootOutput_forATorGCbias,
                                    rootInput_forATorGCbias = rootInput_forATorGCbias,
                                    fullGC_b = fullGC_b,
                                    dumpFourier_b = dumpFourier_b,
                                    dumpFileNamePrefix = dumpFileNamePrefix, 
                                    modelFileName_forATorGCbias = modelFileName_forATorGCbias)
# Out:
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr1/FourierOnPredReturn/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr1/GCbias_predReturn_R64_chr1_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 39135.000000 (3.855938)
# After stop (2000) the max (min) modulus of Fourier coeff is: 950.104187 (0.896689)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr1/GCbias_predReturn_R64_chr1_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 39455.000000 (3.488686)
# After stop (2000) the max (min) modulus of Fourier coeff is: 812.552551 (0.740524)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr1/GCbias_predReturn_R64_chr1_seg100000_segment2_avgRevCompl0_win1_step1
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr2/FourierOnPredReturn/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr2/GCbias_predReturn_R64_chr2_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 38526.000000 (5.399194)
# After stop (2000) the max (min) modulus of Fourier coeff is: 991.838562 (0.498854)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr2/GCbias_predReturn_R64_chr2_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38442.000000 (1.694917)
# After stop (2000) the max (min) modulus of Fourier coeff is: 899.119202 (0.852205)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr2/GCbias_predReturn_R64_chr2_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38137.000000 (6.597044)
# After stop (2000) the max (min) modulus of Fourier coeff is: 1018.014709 (0.678377)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr2/GCbias_predReturn_R64_chr2_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37965.000000 (2.864600)
# After stop (2000) the max (min) modulus of Fourier coeff is: 708.887146 (0.735072)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr2/GCbias_predReturn_R64_chr2_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38670.000000 (5.712512)
# After stop (2000) the max (min) modulus of Fourier coeff is: 947.602356 (0.590547)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr2/GCbias_predReturn_R64_chr2_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37394.000000 (3.138423)
# After stop (2000) the max (min) modulus of Fourier coeff is: 804.118591 (0.482632)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr2/GCbias_predReturn_R64_chr2_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 39083.000000 (3.007717)
# After stop (2000) the max (min) modulus of Fourier coeff is: 918.461243 (0.892669)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr2/GCbias_predReturn_R64_chr2_seg100000_segment7_avgRevCompl0_win1_step1
# 7 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38455.000000 (6.049281)
# After stop (2000) the max (min) modulus of Fourier coeff is: 886.269226 (0.578526)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr2/GCbias_predReturn_R64_chr2_seg100000_segment8_avgRevCompl0_win1_step1
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr3/FourierOnPredReturn/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr3/GCbias_predReturn_R64_chr3_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 39102.000000 (2.061519)
# After stop (2000) the max (min) modulus of Fourier coeff is: 740.832458 (0.441258)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr3/GCbias_predReturn_R64_chr3_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37197.000000 (3.212271)
# After stop (2000) the max (min) modulus of Fourier coeff is: 598.906738 (0.452759)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr3/GCbias_predReturn_R64_chr3_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 39289.000000 (1.296322)
# After stop (2000) the max (min) modulus of Fourier coeff is: 1063.220215 (0.936816)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr3/GCbias_predReturn_R64_chr3_seg100000_segment3_avgRevCompl0_win1_step1
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/FourierOnPredReturn/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 38375.000000 (1.257565)
# After stop (2000) the max (min) modulus of Fourier coeff is: 866.031555 (0.367266)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38615.000000 (1.860952)
# After stop (2000) the max (min) modulus of Fourier coeff is: 854.235840 (0.686210)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38235.000000 (0.962727)
# After stop (2000) the max (min) modulus of Fourier coeff is: 948.962097 (0.620680)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38186.000000 (4.063469)
# After stop (2000) the max (min) modulus of Fourier coeff is: 1014.057739 (0.523170)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37698.000000 (4.765543)
# After stop (2000) the max (min) modulus of Fourier coeff is: 706.232666 (0.813331)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37472.000000 (2.361251)
# After stop (2000) the max (min) modulus of Fourier coeff is: 542.990051 (0.082026)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37508.000000 (4.288541)
# After stop (2000) the max (min) modulus of Fourier coeff is: 904.683228 (0.726819)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment7_avgRevCompl0_win1_step1
# 7 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37631.000000 (3.301439)
# After stop (2000) the max (min) modulus of Fourier coeff is: 1074.510132 (0.768834)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment8_avgRevCompl0_win1_step1
# 8 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37892.000000 (0.864101)
# After stop (2000) the max (min) modulus of Fourier coeff is: 862.849915 (0.196460)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment9_avgRevCompl0_win1_step1
# 9 (100000,)
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37629.000000 (1.740185)
# After stop (2000) the max (min) modulus of Fourier coeff is: 888.740234 (0.529046)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment10_avgRevCompl0_win1_step1
# 10 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37375.000000 (4.920184)
# After stop (2000) the max (min) modulus of Fourier coeff is: 720.126709 (0.741546)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment11_avgRevCompl0_win1_step1
# 11 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37339.000000 (3.271866)
# After stop (2000) the max (min) modulus of Fourier coeff is: 1024.765259 (0.290008)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment12_avgRevCompl0_win1_step1
# 12 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38006.000000 (5.178987)
# After stop (2000) the max (min) modulus of Fourier coeff is: 670.478638 (0.220259)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment13_avgRevCompl0_win1_step1
# 13 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38110.000000 (3.837377)
# After stop (2000) the max (min) modulus of Fourier coeff is: 982.680603 (0.325212)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment14_avgRevCompl0_win1_step1
# 14 (100000,)
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38188.000000 (3.895235)
# After stop (2000) the max (min) modulus of Fourier coeff is: 741.861450 (0.847426)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr4/GCbias_predReturn_R64_chr4_seg100000_segment15_avgRevCompl0_win1_step1
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr5/FourierOnPredReturn/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr5/GCbias_predReturn_R64_chr5_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 39171.003906 (0.558704)
# After stop (2000) the max (min) modulus of Fourier coeff is: 724.364502 (0.134348)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr5/GCbias_predReturn_R64_chr5_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37870.000000 (1.001016)
# After stop (2000) the max (min) modulus of Fourier coeff is: 697.037964 (1.302505)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr5/GCbias_predReturn_R64_chr5_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38470.000000 (5.784386)
# After stop (2000) the max (min) modulus of Fourier coeff is: 726.994995 (0.508579)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr5/GCbias_predReturn_R64_chr5_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38571.000000 (7.755730)
# After stop (2000) the max (min) modulus of Fourier coeff is: 737.434021 (0.447095)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr5/GCbias_predReturn_R64_chr5_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38311.000000 (3.292802)
# After stop (2000) the max (min) modulus of Fourier coeff is: 778.410522 (0.149960)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr5/GCbias_predReturn_R64_chr5_seg100000_segment5_avgRevCompl0_win1_step1
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr6/FourierOnPredReturn/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr6/GCbias_predReturn_R64_chr6_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 39447.000000 (3.155544)
# After stop (2000) the max (min) modulus of Fourier coeff is: 748.699524 (0.390636)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr6/GCbias_predReturn_R64_chr6_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37861.000000 (4.244049)
# After stop (2000) the max (min) modulus of Fourier coeff is: 803.977234 (0.678442)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr6/GCbias_predReturn_R64_chr6_seg100000_segment2_avgRevCompl0_win1_step1
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr7/FourierOnPredReturn/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr7/GCbias_predReturn_R64_chr7_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# ...
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38306.000000 (1.972946)
# After stop (2000) the max (min) modulus of Fourier coeff is: 752.990601 (0.386541)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr15/GCbias_predReturn_R64_chr15_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38445.000000 (3.331140)
# After stop (2000) the max (min) modulus of Fourier coeff is: 760.962830 (0.256749)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr15/GCbias_predReturn_R64_chr15_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37521.000000 (2.689893)
# After stop (2000) the max (min) modulus of Fourier coeff is: 711.439270 (1.315522)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr15/GCbias_predReturn_R64_chr15_seg100000_segment7_avgRevCompl0_win1_step1
# 7 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37838.000000 (6.334293)
# After stop (2000) the max (min) modulus of Fourier coeff is: 802.563293 (0.587268)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr15/GCbias_predReturn_R64_chr15_seg100000_segment8_avgRevCompl0_win1_step1
# 8 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37807.000000 (2.591267)
# After stop (2000) the max (min) modulus of Fourier coeff is: 871.201538 (1.348981)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr15/GCbias_predReturn_R64_chr15_seg100000_segment9_avgRevCompl0_win1_step1
# 9 (100000,)
# 100000
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38331.000000 (0.763626)
# After stop (2000) the max (min) modulus of Fourier coeff is: 1028.242310 (0.629951)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr15/GCbias_predReturn_R64_chr15_seg100000_segment10_avgRevCompl0_win1_step1
# Directory /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/FourierOnPredReturn/20to2000/ created. Output will be placed there.
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/GCbias_predReturn_R64_chr16_seg100000_segment0_avgRevCompl0_win1_step1
# 0 (99950,)
# 99950
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6875: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6876: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6877: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1, ax1 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6878: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6879: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2, ax2 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:6880: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# avgPredArray size:  99950
# ratioQ:  1.0
# Fourier transf lenght:  99950
# frqs  [ 0.00000000e+00  1.00050025e-05  2.00100050e-05 ... -3.00150075e-05
#  -2.00100050e-05 -1.00050025e-05]
# First 10 (positive) frqs:  [0.00000000e+00 1.00050025e-05 2.00100050e-05 3.00150075e-05
#  4.00200100e-05 5.00250125e-05 6.00300150e-05 7.00350175e-05
#  8.00400200e-05 9.00450225e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.00050025e-05 -2.00100050e-05 -3.00150075e-05 -4.00200100e-05
#  -5.00250125e-05 -6.00300150e-05 -7.00350175e-05 -8.00400200e-05
#  -9.00450225e-05 -1.00050025e-04]
# Up to stop (2000) with frq 0.020010, the max (min) modulus of Fourier coeff is: 38689.003906 (1.614296)
# After stop (2000) the max (min) modulus of Fourier coeff is: 723.897400 (0.540813)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/GCbias_predReturn_R64_chr16_seg100000_segment1_avgRevCompl0_win1_step1
# 1 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38260.000000 (2.573526)
# After stop (2000) the max (min) modulus of Fourier coeff is: 1055.551636 (0.469753)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/GCbias_predReturn_R64_chr16_seg100000_segment2_avgRevCompl0_win1_step1
# 2 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37720.000000 (2.430522)
# After stop (2000) the max (min) modulus of Fourier coeff is: 671.109314 (0.585198)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/GCbias_predReturn_R64_chr16_seg100000_segment3_avgRevCompl0_win1_step1
# 3 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38117.000000 (4.540146)
# After stop (2000) the max (min) modulus of Fourier coeff is: 812.011169 (0.441618)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/GCbias_predReturn_R64_chr16_seg100000_segment4_avgRevCompl0_win1_step1
# 4 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37994.000000 (1.448889)
# After stop (2000) the max (min) modulus of Fourier coeff is: 706.109985 (0.292580)
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7004: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig0, ax0 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7005: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig1_loc, ax1_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7006: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig2_loc, ax2_loc = plt.subplots()
# /content/drive/MyDrive/DNA_proj/development/dnaNet_stats_py3.py:7007: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig3, ax3 = plt.subplots()
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/GCbias_predReturn_R64_chr16_seg100000_segment5_avgRevCompl0_win1_step1
# 5 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37816.000000 (2.446056)
# After stop (2000) the max (min) modulus of Fourier coeff is: 1092.704956 (0.352133)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/GCbias_predReturn_R64_chr16_seg100000_segment6_avgRevCompl0_win1_step1
# 6 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38080.000000 (1.625258)
# After stop (2000) the max (min) modulus of Fourier coeff is: 764.603149 (0.274677)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/GCbias_predReturn_R64_chr16_seg100000_segment7_avgRevCompl0_win1_step1
# 7 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 37524.000000 (1.535277)
# After stop (2000) the max (min) modulus of Fourier coeff is: 695.751648 (1.093943)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/GCbias_predReturn_R64_chr16_seg100000_segment8_avgRevCompl0_win1_step1
# 8 (100000,)
# 100000
# ratioQ:  1.0
# Fourier transf lenght:  100000
# frqs  [ 0.e+00  1.e-05  2.e-05 ... -3.e-05 -2.e-05 -1.e-05]
# First 10 (positive) frqs:  [0.e+00 1.e-05 2.e-05 3.e-05 4.e-05 5.e-05 6.e-05 7.e-05 8.e-05 9.e-05]
# Largest (positive) frq: -0.500000
# First 10 (negative) frqs:  [-1.e-05 -2.e-05 -3.e-05 -4.e-05 -5.e-05 -6.e-05 -7.e-05 -8.e-05 -9.e-05
#  -1.e-04]
# Up to stop (2000) with frq 0.020000, the max (min) modulus of Fourier coeff is: 38126.000000 (3.540286)
# After stop (2000) the max (min) modulus of Fourier coeff is: 699.919067 (0.580020)
# /content/drive/MyDrive/DNA_proj/results/GCbias/R64_chr16/GCbias_predReturn_R64_chr16_seg100000_segment9_avgRevCompl0_win1_step1

# %% [markdown]
# The output plots should now sit in FourierOnPredReturn/20To2000 subfolders of the GCbias/chrNN folders.
